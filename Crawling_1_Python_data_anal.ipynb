# %% [markdown]
# # 5주차 데이터 수집 (크롤링)
#
# 데이터를 수집하는 방법은 여러가지가 있습니다. csv(comma seperated values)나 엑셀과 같이 이미 정리된 [파일 형식으로 데이터](http://datalab.naver.com/)를 얻을 수도 있고, Database나 [API](https://developers.naver.com/products/login/api)를 통해 얻을수도 있지만, 오늘은 **웹 크롤링**을 통해 데이터를 수집하는 방법에 대해서 배워보겠습니다. Web crawling은 Web scraping라고도 말하는데, 위키피디아에 따르면 **'조직적이고 자동화된 방법으로 월드 와이드 웹을 탐색하는 방법’**이라고 나와있네요. HTML 파일을 긁어서 필요한 정보들만 뽑아 csv 파일로 저장하는 방법에 대해 배워보겠습니다.
#
# 웹사이트 크롤링을 하기 위해선 **우선 웹사이트를 구성하고 있는 HTML, CSS**에 대한 기본적인 지식이 필요합니다.

# %%
## HTML과 CSS에 대한 기본 지식
# - [W3School](http://www.w3schools.com/html/)
# - [codeacademy](https://www.codecademy.com/learn/web)

### 1. 파이참에서 index.html파일을 만들어봅시다.
### 2. 바꿔봅시다!



# ```

# 1. 마우스 오른쪽 버튼 -> 검사
# 2. 마우스 오른쪽 버튼 -> Copy -> CSS Selector
# 3. body > div > div.desc-line.second

# ### 3. style 태그 대신 style.css 파일에 정리해둘 수도 있습니다.
# `<head>`에 추가해주세요.

# ```html
# <link rel="stylesheet" href="style.css">
# ```

# %% [markdown]
# ## 오늘 수업에 필요한 패키지를 설치해주세요
#
# # pip install beautifulsoup4
# # pip install requests
# # pip install urllib3
#
#
# 개발 도중 사용법에 대해 궁금한 것들이 있으면 Document를 참고해보세요.
# - [beautifulsoup4](http://coreapython.hosting.paran.com/etc/beautifulsoup4.html): HTML로 부터 데이터를 뽑아내기 위한 라이브러리입니다.
# - [requests](http://docs.python-requests.org/en/master/): requests.get을 통해 HTML을 받아올 수 있습니다.
# - [urllib3](https://urllib3.readthedocs.org/en/latest/): HTTP 통신을 도와주는 패키지입니다.

# %% [markdown]
# ## HTML과 CSS에 대한 기본 지식
# - [W3School](http://www.w3schools.com/html/)
# - [codeacademy](https://www.codecademy.com/learn/web)
#
# ### 1. 파이참에서 index.html파일을 만들어봅시다.
# ### 2. 바꿔봅시다!
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>파이썬 클래스</title>
#     <meta property="og:title" content="페이스북이나 카톡 미리보기에서 보이는 제목입니다." />
#     <meta property="og:description" content="og 설명" />
#     <meta property="og:image" content="og 이미지" />
#     <style>
#         body {
#             background-color: #d0e4fe;
#         }
#
#         h1 {
#             color: orange;
#             text-align: center;
#         }
#
#         .desc-box {
#             text-align: center;
#         }
#
#         #desc-important {
#             color: blue;
#         }
#     </style>
# </head>
# <body>
#
# <h1>파이썬 2016 클래스입니다.</h1>
#
# <div class="desc-box">
#     <p>오늘은 <b id="crawling">크롤링</b>에 대해 배우고 있습니다.</p>
#
#     <div>
#         <img src="http://movement-as-medicine.com/wp-content/uploads/2014/01/baby-crawling.jpg"/>
#     </div>
#
#     <span>크롤링에 대한 자세한 정의는 <a href="https://en.wikipedia.org/wiki/Web_crawler">위키피디아</a>를 참고해보세요.</span>
#
#     <div class="desc-line first">
#         <span>웹 크롤링을 하려면 html과 css에 대해 먼저 알아야 합니다.</span>
#         <a href="http://www.w3schools.com/html/">w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요</a>
#     </div>
#     <div class="desc-line second">
#         <span><b id="desc-important">Javascript</b>는 웹페이지를 동적으로 만들어주는 역할을 합니다.</span>
#     </div>
# </div>
#
# </body>
# </html>
# ```
#
# 1. 마우스 오른쪽 버튼 -> 검사
# 2. 마우스 오른쪽 버튼 -> Copy -> CSS Selector
# 3. body > div > div.desc-line.second
#
# ### 3. style 태그 대신 style.css 파일에 정리해둘 수도 있습니다.
# `<head>`에 추가해주세요.
#
# ```html
# <link rel="stylesheet" href="style.css">
# ```

# %%
import requests

from bs4 import BeautifulSoup as bs

# response = requests.get('./index.html')
# response.status_code

# %%
f =  open("./index.html", 'rb', en)
index = f.read()
print (index)
f.close()
# Out:
# b'<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <meta charset="UTF-8">\r\n    <title>\xed\x8c\x8c\xec\x9d\xb4\xec\x8d\xac \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4</title>\r\n    <meta property="og:title" content="\xed\x8e\x98\xec\x9d\xb4\xec\x8a\xa4\xeb\xb6\x81\xec\x9d\xb4\xeb\x82\x98 \xec\xb9\xb4\xed\x86\xa1 \xeb\xaf\xb8\xeb\xa6\xac\xeb\xb3\xb4\xea\xb8\xb0\xec\x97\x90\xec\x84\x9c \xeb\xb3\xb4\xec\x9d\xb4\xeb\x8a\x94 \xec\xa0\x9c\xeb\xaa\xa9\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4." />\r\n    <meta property="og:description" content="og \xec\x84\xa4\xeb\xaa\x85" />\r\n    <meta property="og:image" content="og \xec\x9d\xb4\xeb\xaf\xb8\xec\xa7\x80" />\r\n    <style>\r\n        body {\r\n            background-color: #d0e4fe;\r\n        }\r\n\r\n        h1 {\r\n            color: orange;\r\n            text-align: center;\r\n        }\r\n\r\n        .desc-box {\r\n            text-align: center;\r\n        }\r\n\r\n        #desc-important {\r\n            color: blue;\r\n        }\r\n    </style>\r\n</head>\r\n<body>\r\n\r\n<h1>\xed\x8c\x8c\xec\x9d\xb4\xec\x8d\xac 2016 \xed\x81\xb4\xeb\x9e\x98\xec\x8a\xa4\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4.</h1>\r\n\r\n<div class="desc-box">\r\n    <p>\xec\x98\xa4\xeb\x8a\x98\xec\x9d\x80 <b id="crawling">\xed\x81\xac\xeb\xa1\xa4\xeb\xa7\x81</b>\xec\x97\x90 \xeb\x8c\x80\xed\x95\xb4 \xeb\xb0\xb0\xec\x9a\xb0\xea\xb3\xa0 \xec\x9e\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.</p>\r\n     <p>p\xed\x83\x9c\xea\xb7\xb8 \xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8.</p>\r\n    <p>p\xed\x83\x9c\xea\xb7\xb8 \xed\x85\x8c\xec\x8a\xa4\xed\x8a\xb8 2.</p>\r\n    <div>\r\n        <img src="http://movement-as-medicine.com/wp-content/uploads/2014/01/baby-crawling.jpg"/>\r\n    </div>\r\n\r\n    <span>\xed\x81\xac\xeb\xa1\xa4\xeb\xa7\x81\xec\x97\x90 \xeb\x8c\x80\xed\x95\x9c \xec\x9e\x90\xec\x84\xb8\xed\x95\x9c \xec\xa0\x95\xec\x9d\x98\xeb\x8a\x94 <a href="https://en.wikipedia.org/wiki/Web_crawler">\xec\x9c\x84\xed\x82\xa4\xed\x94\xbc\xeb\x94\x94\xec\x95\x84</a>\xeb\xa5\xbc \xec\xb0\xb8\xea\xb3\xa0\xed\x95\xb4\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94.</span>\r\n    <a href="https://en.wikipedia.org/wiki/Web_crawler">a\xed\x83\x9c\xea\xb7\xb8 \xec\x97\xb0\xec\x8a\xb5\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4</a>\r\n    <a href="https:/www.naver.com">\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4</a>\r\n\r\n    <div class="desc-line first">\r\n        <span>\xec\x9b\xb9 \xed\x81\xac\xeb\xa1\xa4\xeb\xa7\x81\xec\x9d\x84 \xed\x95\x98\xeb\xa0\xa4\xeb\xa9\xb4 html\xea\xb3\xbc css\xec\x97\x90 \xeb\x8c\x80\xed\x95\xb4 \xeb\xa8\xbc\xec\xa0\x80 \xec\x95\x8c\xec\x95\x84\xec\x95\xbc \xed\x95\xa9\xeb\x8b\x88\xeb\x8b\xa4.</span>\r\n        <a href="http://www.w3schools.com/html/">w3school \xed\x8e\x98\xec\x9d\xb4\xec\xa7\x80\xec\x97\x90\xec\x84\x9c HTML, CSS\xec\x97\x90 \xeb\x8c\x80\xed\x95\xb4 \xec\x95\x8c\xec\x95\x84\xeb\xb3\xbc \xec\x88\x98 \xec\x9e\x88\xec\x96\xb4\xec\x9a\x94</a>\r\n    </div>\r\n    <div class="desc-line second">\r\n        <span><b id="desc-important">Javascript</b>\xeb\x8a\x94 \xec\x9b\xb9\xed\x8e\x98\xec\x9d\xb4\xec\xa7\x80\xeb\xa5\xbc \xeb\x8f\x99\xec\xa0\x81\xec\x9c\xbc\xeb\xa1\x9c \xeb\xa7\x8c\xeb\x93\xa4\xec\x96\xb4\xec\xa3\xbc\xeb\x8a\x94 \xec\x97\xad\xed\x95\xa0\xec\x9d\x84 \xed\x95\xa9\xeb\x8b\x88\xeb\x8b\xa4.</span>\r\n    </div>\r\n</div>\r\n\r\n</body>\r\n</html>'

# %%
soup = bs( index, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>파이썬 클래스</title>
# <meta content="페이스북이나 카톡 미리보기에서 보이는 제목입니다." property="og:title"/>
# <meta content="og 설명" property="og:description"/>
# <meta content="og 이미지" property="og:image"/>
# <style>
#         body {
#             background-color: #d0e4fe;
#         }
#
#         h1 {
#             color: orange;
#             text-align: center;
#         }
#
#         .desc-box {
#             text-align: center;
#         }
#
#         #desc-important {
#             color: blue;
#         }
#     </style>
# </head>
# <body>
# <h1>파이썬 2016 클래스입니다.</h1>
# <div class="desc-box">
# <p>오늘은 <b id="crawling">크롤링</b>에 대해 배우고 있습니다.</p>
# <p>p태그 테스트.</p>
# <p>p태그 테스트 2.</p>
# <div>
# <img src="http://movement-as-medicine.com/wp-content/uploads/2014/01/baby-crawling.jpg"/>
# </div>
# <span>크롤링에 대한 자세한 정의는 <a href="https://en.wikipedia.org/wiki/Web_crawler">위키피디아</a>를 참고해보세요.</span>
# <a href="https://en.wikipedia.org/wiki/Web_crawler">a태그 연습입니다</a>
# <a href="https:/www.naver.com">네이버입니다</a>
# <div class="desc-line first">
# <span>웹 크롤링을 하려면 html과 css에 대해 먼저 알아야 합니다.</span>
# <a href="http://www.w3schools.com/html/">w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요</a>
# </div>
# <div class="desc-line second">
# <span><b id="desc-important">Javascript</b>는 웹페이지를 동적으로 만들어주는 역할을 합니다.</span>
# </div>
# </div>
# </body>
# </html>

# %%
soup.text
# Out:
# '\n\n\n파이썬 클래스\n\n\n\n\r\n        body {\r\n            background-color: #d0e4fe;\r\n        }\r\n\r\n        h1 {\r\n            color: orange;\r\n            text-align: center;\r\n        }\r\n\r\n        .desc-box {\r\n            text-align: center;\r\n        }\r\n\r\n        #desc-important {\r\n            color: blue;\r\n        }\r\n    \n\n\n파이썬 2016 클래스입니다.\n\n오늘은 크롤링에 대해 배우고 있습니다.\np태그 테스트.\np태그 테스트 2.\n\n\n\n크롤링에 대한 자세한 정의는 위키피디아를 참고해보세요.\na태그 연습입니다\n네이버입니다\n\n웹 크롤링을 하려면 html과 css에 대해 먼저 알아야 합니다.\nw3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요\n\n\nJavascript는 웹페이지를 동적으로 만들어주는 역할을 합니다.\n\n\n\n'

# %%
# soup 객체로부터 쉽게 parsing된 데이터들을 받아올 수 있습니다.

# title 태그를 받아옵니다.
print (soup.title)

# 태그 이름을 받아옵니다.
print (soup.title.name)

# 태그 내 문자열을 가져옵니다.
print (soup.title.text)

# 부모 태그를 가져옵니다.
print (soup.title.parent.name)
 
# p 태그를 가져옵니다.
print (soup.p)
# Out:
# <title>파이썬 클래스</title>
# title
# 파이썬 클래스
# head
# <p>오늘은 <b id="crawling">크롤링</b>에 대해 배우고 있습니다.</p>

# %%
# 모든 a 태그 가져오기

print (soup.a)
print ("-------")
print (soup.find_all('a'))
print ("-------")
print (soup.find('a'))
print ("-------")
print (soup.select('a'))

print ("-------")
atext = soup.select('a')

for i in range(len(atext)):
    print (atext[i].text)
# Out:
# <a href="https://en.wikipedia.org/wiki/Web_crawler">위키피디아</a>
# -------
# [<a href="https://en.wikipedia.org/wiki/Web_crawler">위키피디아</a>, <a href="https://en.wikipedia.org/wiki/Web_crawler">a태그 연습입니다</a>, <a href="https:/www.naver.com">네이버입니다</a>, <a href="http://www.w3schools.com/html/">w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요</a>]
# -------
# <a href="https://en.wikipedia.org/wiki/Web_crawler">위키피디아</a>
# -------
# [<a href="https://en.wikipedia.org/wiki/Web_crawler">위키피디아</a>, <a href="https://en.wikipedia.org/wiki/Web_crawler">a태그 연습입니다</a>, <a href="https:/www.naver.com">네이버입니다</a>, <a href="http://www.w3schools.com/html/">w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요</a>]
# -------
# 위키피디아
# a태그 연습입니다
# 네이버입니다
# w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요

# %%
# 클래스명으로 가져오기
print (soup.select('.desc-line.first '))
# Out:
# [<div class="desc-line first">
# <span>웹 크롤링을 하려면 html과 css에 대해 먼저 알아야 합니다.</span>
# <a href="http://www.w3schools.com/html/">w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요</a>
# </div>]

# %%
# id로 가져오기
print (soup.select('#desc-important'))
# Out:
# [<b id="desc-important">Javascript</b>]

# %%
# CSS path로 가져오기
print (soup.select('body > div.desc-box > div.desc-line.first > span '))
# Out:
# [<span>웹 크롤링을 하려면 html과 css에 대해 먼저 알아야 합니다.</span>]

# %%
# 속성(attr)으로 가져오기
print (soup.find_all('a',{'href' : 'http://www.w3schools.com/html/'}))
# Out:
# [<a href="http://www.w3schools.com/html/">w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요</a>]

# %%
# 속성(attr)으로 가져오기
print (soup.findAll('a',{'href' : 'http://www.w3schools.com/html/'}))
# Out:
# [<a href="http://www.w3schools.com/html/">w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요</a>]

# %%
# 속성(attr)으로 가져오기
print (soup.find_all('a', {'href' : 'https://en.wikipedia.org/wiki/Web_crawler'}))
# Out:
# [<a href="https://en.wikipedia.org/wiki/Web_crawler">위키피디아</a>, <a href="https://en.wikipedia.org/wiki/Web_crawler">a태그 연습입니다</a>]

# %%
# 클래스명도 속성 중 하나이기 때문에 이런식으로 가져올 수 있습니다.
# 클래스 텍스트만 뽑아오기
    
print (soup.find_all('div', {'class' : 'desc-line'}))
print ("--------  ")

atext = soup.find_all('div', {'class' : 'desc-line'})


for i in range(len(atext)):
    print (atext[i].text)
# Out:
# [<div class="desc-line first">
# <span>웹 크롤링을 하려면 html과 css에 대해 먼저 알아야 합니다.</span>
# <a href="http://www.w3schools.com/html/">w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요</a>
# </div>, <div class="desc-line second">
# <span><b id="desc-important">Javascript</b>는 웹페이지를 동적으로 만들어주는 역할을 합니다.</span>
# </div>]
# --------
#
# 웹 크롤링을 하려면 html과 css에 대해 먼저 알아야 합니다.
# w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요
#
#
# Javascript는 웹페이지를 동적으로 만들어주는 역할을 합니다.

# %%
# 자, 이제 필요한 HTML 태그를 뽑는 것 까지 가능합니다. 
# 태그 안에 속성(src, href 등)이나 text를 뽑아내는 방법에 대해 알아봅시다. 

# text만 뽑아내기
print (soup.select('.desc-line.first').text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-32bdb432c6b5> in <module>()
#       3
#       4 # text만 뽑아내기
# ----> 5 print (soup.select('.desc-line.first').text)
#
# AttributeError: 'list' object has no attribute 'text'

# %%
# text만 뽑아내기
print (soup.select('.desc-line.first')[0].text)
# Out:
# 웹 크롤링을 하려면 html과 css에 대해 먼저 알아야 합니다.
# w3school 페이지에서 HTML, CSS에 대해 알아볼 수 있어요

# %%
# a 태그 href 뽑아내기
a_tag = soup.select('body > div > span > a')
print (len(a_tag))
print (a_tag)
print (a_tag[0].attrs)
print (a_tag[0]['href'])
# Out:
# 1
# [<a href="https://en.wikipedia.org/wiki/Web_crawler">위키피디아</a>]
# {'href': 'https://en.wikipedia.org/wiki/Web_crawler'}
# https://en.wikipedia.org/wiki/Web_crawler

# %%
print (imgt.attrs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-05f1f3acf00b> in <module>()
# ----> 1 print (imgt.attrs)
#
# AttributeError: 'list' object has no attribute 'attrs'

# %%
# img 태그 src 뽑아내기

imgt = soup.select('img')
print (imgt)

print (imgt[0].attrs)
print (imgt[0]['src'])
print ("  ")
print ("  ")
# Out:
# [<img src="http://movement-as-medicine.com/wp-content/uploads/2014/01/baby-crawling.jpg"/>]
# {'src': 'http://movement-as-medicine.com/wp-content/uploads/2014/01/baby-crawling.jpg'}
# http://movement-as-medicine.com/wp-content/uploads/2014/01/baby-crawling.jpg

# %% [markdown]
# 이제 **beautifulsoup 기본기**는 닦은 것 같습니다. **requests** 라이브러리를 사용해 월드 와이드 웹 세상의 html을 받아옵시다.

# %%
# pip를 통해 설치한 requests를 import합니다.
import requests

# %%
# 무료 이미지들을 크롤링해봅시다.
res = requests.get('https://pixabay.com/en/')

# dir()은 해당 객체의 사용 가능한 속성(attributes)를 list로 리턴해줍니다.
# print dir(res) 

# HTTP 요청을 보내면 응답으로 Status Code가 오게 됩니다.
# 200: 성공
# 404: 페이지 없음
# 500: 서버 오류
# => https://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C

# HTTP란 WWW에서 사용하는 약속(protocol)입니다. 
# 여러분들의 컴퓨터(클라이언트)와 네이버의 컴퓨터(서버)가 통신을 하는데 있어, 
# '어떤 메시지 형식으로 주고 받을 것이다.'하고 약속을 하고 0101..의 이진수를 주고 받는 것 이지요.
# 이러한 약속을 미리 공유하고 있어야 메시지를 올바르게 해석할 수 있습니다.

# 200번이면 성공적으로 잘 받아온겁니다.
print (res.status_code)
# print res.text
# Out:
# 200

# %%
# bs(open('./index.html')) 했던 것 처럼, index.html 자리에 res.text를 넣어줍니다.
# python에서 open은 파일을 읽거나 쓸때 사용됩니다.
# 여기서 open 또한 index.html '파일'을 읽어오기 위해 사용된 것입니다.
# res.text는 그 자체가 html이므로 open을 사용할 필요가 없습니다.
pixabay_html = bs(res.text)

# 메인 페이지의 이미지를 받아서, 로컬 컴퓨터에 저장해보세요.
# 이미지를 로컬 컴퓨터에 다운받으려면 urllib 라이브러리를 사용하면 됩니다.
# pip install urllib3
# import urllib
# def download_image(img_src, filename):
#     res = urllib.urlretrieve(img_src, filename)
#     return res
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
import requests
import urllib.request


def download_image(img_addr, img_name):
    res = urllib.request.urlretrieve(img_addr, img_name)
    return res

# %%
response = requests.get('https://pixabay.com/en')
response.status_code
# Out:
# 200

# %%
dom = bs(response.text)
print (dom)
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#">
# <head><meta charset="utf-8"/>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#4ea64e" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#4ea64e" name="msapplication-TileColor"/>
# <meta content="/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#4ea64e" name="theme-color"/>
# <link href="https://pixabay.com/static/misc/opensearch.xml" rel="search" title="Pixabay" type="application/opensearchdescription+xml"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/static/css/base25.min.css" rel="stylesheet"/>
# <!--[if lt IE 9]><script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script><![endif]-->
# <title>Free Images - Pixabay</title>
# <link href="/" rel="canonical"/>
# <meta content="Over 680,000 high quality photos, illustrations, and vector graphics. Free for commercial use. No attribution required." name="description"/>
# <meta content="https://pixabay.com/static/img/logo_square.png" property="og:image"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@pixabay" name="twitter:site"/>
# <meta content="Free Images - Pixabay" name="twitter:title"/>
# <meta content="Over 680,000 high quality photos, illustrations, and vector graphics. Free for commercial use. No attribution required." name="twitter:description"/>
# <meta content="https://pixabay.com/static/img/logo_square.png" name="twitter:image:src"/>
# </head>
# <body class="no_header_search">
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-5CF9ZN" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-5CF9ZN');</script>
# <div id="wrapper">
# <div id="header"><div id="header_inner">
# <div class="pure-menu pure-menu-horizontal pure-menu-open">
# <ul><li class="pure-dropdown hide-xs hide-sm hide-md"><a href="/en/editors_choice/">Explore <i class="arrow"></i></a><ul class="pure-menu-children"><li class="mm_inc"><a href="/en/editors_choice/">Editor's Choice</a></li><li class="mm_inc"><a href="/en/photos/">Images</a></li><li class="mm_inc mm_sep"><a href="/en/videos/">Videos</a></li><li class="pure-menu-separator"></li><li class="mm_inc"><a href="/en/users/">Photographers</a></li><li class="mm_inc mm_sep"><a href="/en/cameras/">Cameras</a></li></ul></li><li class="hide-xs hide-sm hide-md mum_inc"><a href="/en/accounts/register/">Sign up</a></li><li class="hide-xs hide-sm hide-md hide-lg mum_inc"><a href="/en/accounts/login/?next=/en/">Log in</a></li><li class="pure-dropdown hide-lg hide-xl"><a><i class="icon icon_menu_user"></i></a><ul class="pure-menu-children" id="mobile_user_menu"></ul></li><li class="pure-dropdown hide-xs hide-sm hide-md"><a><i class="icon icon_menu_dots"></i></a><ul class="pure-menu-children"><li class="mm_inc"><a href="/en/service/faq/">FAQ</a></li><li class="mm_inc"><a href="/en/forum/">Forum</a></li><li class="mm_inc"><a href="/en/blog/">Blog</a></li></ul></li><li class="pure-dropdown hide-lg hide-xl"><a><i class="icon icon_menu_bars"></i></a><ul class="pure-menu-children" id="mobile_menu"></ul></li></ul>
# </div>
# <a class="hover_opacity" href="/" id="logo"></a>
# </div></div>
# <div class="clearfix" id="content">
# <div id="hero">
# <div id="top">
# <h1>Free High Quality Images</h1>
# <h2>Over 680,000 free stock photos, vectors and art illustrations</h2>
# </div>
# <a href="/en/daisy-heart-flowers-flower-heart-712892/" id="bg_link"></a>
# <div style="max-width:640px;position:relative;padding:0 20px;margin:16px auto 124px">
# <form action="/en/photos/" class="media_search search_xl" method="get"><table><tr><td><input data-autofocus="" id="id_q" name="q" placeholder="Search images, vectors and videos" type="text" value=""/></td><td class="hide-xs"><div class="dd_box"><span class="image_type hide-sm" style="margin-right:5px">All images</span><i class="arrow"></i></div><div class="pure-form bubble sw"><table><tr><th>Media type</th><td><label><input checked="" name="image_type" type="radio" value=""/> All images</label><label><input name="image_type" type="radio" value="photo"/> Photos</label><label><input name="image_type" type="radio" value="vector"/> Vector graphics</label><label><input name="image_type" type="radio" value="illustration"/> Illustrations</label><label><input name="image_type" type="radio" value="video"/> Videos</label></td></tr><tr class="image_option"><th>Orientation</th><td><label><input name="orientation" type="checkbox" value="horizontal"/> Horizontal</label><label><input name="orientation" type="checkbox" value="vertical"/> Vertical</label></td></tr><tr class="video_option"><th>Effects</th><td><label><input name="animation" type="checkbox" value="1"/> Animation</label><label><input name="slow_motion" type="checkbox" value="1"/> Slow Motion</label><label><input name="time_lapse" type="checkbox" value="1"/> Time Lapse</label></td></tr><tr><th style="vertical-align:middle">Category</th><td><select name="cat"><option selected="" value="">All</option><option value="animals">Animals</option><option value="buildings">Architecture/Buildings</option><option value="backgrounds">Backgrounds/Textures</option><option value="fashion">Beauty/Fashion</option><option value="business">Business/Finance</option><option value="computer">Computer/Communication</option><option value="education">Education</option><option value="feelings">Emotions</option><option value="food">Food/Drink</option><option value="health">Health/Medical</option><option value="industry">Industry/Craft</option><option value="music">Music</option><option value="nature">Nature/Landscapes</option><option value="people">People</option><option value="places">Places/Monuments</option><option value="religion">Religion</option><option value="science">Science/Technology</option><option value="sports">Sports</option><option value="transportation">Transportation/Traffic</option><option value="travel">Travel/Vacation</option></select></td></tr><tr class="image_option"><th style="vertical-align:middle">Larger than</th><td style="ccolor:#777"><input name="min_width" placeholder="Width" type="text" value=""/><span class="times">×</span><input name="min_height" placeholder="Height" type="text" value=""/> px
#                 </td></tr><tr class="image_option"><th>Color</th><td><label><input name="colors" type="checkbox" value="transparent"/> Transparent</label><input class="cf_grayscale" id="cf_grayscale" name="colors" style="float:none" type="checkbox" value="grayscale"/><label for="cf_grayscale" style="display:inline"> Black and white</label><div class="color_filter bg_colors"><input id="cf_red" name="colors" type="checkbox" value="red"/><label class="red" for="cf_red"></label><input id="cf_orange" name="colors" type="checkbox" value="orange"/><label class="orange" for="cf_orange"></label><input id="cf_yellow" name="colors" type="checkbox" value="yellow"/><label class="yellow" for="cf_yellow"></label><input id="cf_green" name="colors" type="checkbox" value="green"/><label class="green" for="cf_green"></label><input id="cf_turquoise" name="colors" type="checkbox" value="turquoise"/><label class="turquoise" for="cf_turquoise"></label><input id="cf_blue" name="colors" type="checkbox" value="blue"/><label class="blue" for="cf_blue"></label><input id="cf_lilac" name="colors" type="checkbox" value="lilac"/><label class="lilac" for="cf_lilac"></label><input id="cf_pink" name="colors" type="checkbox" value="pink"/><label class="pink" for="cf_pink"></label><input id="cf_white" name="colors" type="checkbox" value="white"/><label class="white" for="cf_white"></label><input id="cf_gray" name="colors" type="checkbox" value="gray"/><label class="gray" for="cf_gray"></label><input id="cf_black" name="colors" type="checkbox" value="black"/><label class="black" for="cf_black"></label><input id="cf_brown" name="colors" type="checkbox" value="brown"/><label class="brown" for="cf_brown"></label></div></td></tr><tr class="video_option"><th>Resolution</th><td><label><input name="resolution_4k" type="checkbox" value="1"/> 4K (2160p)</label><label><input name="resolution_hd" type="checkbox" value="1"/> HD (1080p)</label></td></tr><tr><th style="font-weight:normal"><a href="#" onclick="$('#search_syntax').slideToggle(200);return false;">more...</a></th><td style="min-width:200px;max-width:250px"><div id="search_syntax" style="display:none;white-space:normal">
#                         You can use AND, OR, NOT and () to refine your search results:
#                         <p style="white-space:nowrap"><i>flower AND (red OR blue) NOT rose</i></p>
#                         Search in user portfolios:
#                         <div style="white-space:nowrap"><i>user:stux flower</i></div></div></td></tr></table></div></td><td style="width:1%"><input type="submit" value=" "/></td></tr></table></form></div>
# <div class="bottom">
# <div class="hover_opacity inverted hide-xs" style="float:left">
# <div class="fb-like" data-href="//www.facebook.com/pixabay" data-layout="button_count" data-show-faces="false" style="position:relative;top:-4px"></div>
#
#                   <a class="twitter-follow-button" data-show-count="false" data-show-screen-name="false" href="//twitter.com/pixabay"></a>
#                   <div class="g-follow" data-annotation="none" data-href="//plus.google.com/+Pixabay" data-rel="publisher"></div>
# </div>
# <span id="hero_nav">
# <span class="ajax" data-href="/?pk=2273&amp;prev" data-target="#hero_nav">‹</span>
# <a href="/en/daisy-heart-flowers-flower-heart-712892/">condesign</a>
# <span class="ajax" data-href="/?pk=2273&amp;next" data-target="#hero_nav">›</span>
# </span>
# </div>
# </div>
# <div class="index">
# <div style="text-align:center;max-width:1024px;margin:auto;padding:10px 20px 40px">
# <h2>Free images and videos you can use anywhere</h2>
# <p style="margin:0 0 35px">
#                 All images and videos on Pixabay are released free of copyrights under Creative Commons CC0. You may download, modify, distribute, and use them royalty free for anything you like, even in commercial applications. Attribution is not required.
#                 <a href="/en/service/faq/">Learn more ...</a>
# </p>
# </div>
# <ul class="tab_menu">
# <li class="selected ajax" data-href="/?gallery&amp;media_type=photo" data-target="#gallery">Photos</li>
# <li class="ajax hide-xs" data-href="/?gallery&amp;media_type=illustration" data-target="#gallery">Illustrations</li>
# <li class="hide-sm hide-xs ajax" data-href="/?gallery&amp;media_type=vector" data-target="#gallery">Vector graphics</li>
# <li class="ajax" data-href="/?gallery&amp;media_type=video" data-target="#gallery">Videos</li>
# </ul>
# <div><div id="gallery">
# <div class="flex_grid credits">
# <div class="item" data-h="640" data-w="463">
# <a href="/en/alcohol-aluminum-barbecue-barbeque-1238646/">
# <img alt="" src="/static/uploads/photo/2016/03/05/20/05/alcohol-1238646__340.jpg" srcset="/static/uploads/photo/2016/03/05/20/05/alcohol-1238646__340.jpg 1x, /static/uploads/photo/2016/03/05/20/05/alcohol-1238646_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 3
#                         <i class="icon icon_favorite"></i> 0
#                         <i class="icon icon_comment"></i> 3
#                     </div>
# <a href="/en/users/Meditations-2077322/">Meditations</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/roll-the-dice-craps-board-game-1502706/">
# <img alt="" src="/static/uploads/photo/2016/07/07/16/46/roll-the-dice-1502706__340.jpg" srcset="/static/uploads/photo/2016/07/07/16/46/roll-the-dice-1502706__340.jpg 1x, /static/uploads/photo/2016/07/07/16/46/roll-the-dice-1502706_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 12
#                         <i class="icon icon_favorite"></i> 7
#                         <i class="icon icon_comment"></i> 11
#                     </div>
# <a href="/en/users/gugue-955169/">gugue</a>
# </div>
# </div>
# <div class="item" data-h="303" data-w="640">
# <a href="/en/leaf-nature-green-spring-abstract-1498985/">
# <img alt="" src="/static/uploads/photo/2016/07/05/16/53/leaf-1498985__340.jpg"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 13
#                         <i class="icon icon_favorite"></i> 10
#                         <i class="icon icon_comment"></i> 11
#                     </div>
# <a href="/en/users/jeonsango-1594796/">jeonsango</a>
# </div>
# </div>
# <div class="item" data-h="395" data-w="640">
# <a href="/en/frog-water-frog-animal-green-1495034/">
# <img alt="" src="/static/uploads/photo/2016/07/03/16/26/frog-1495034__340.jpg" srcset="/static/uploads/photo/2016/07/03/16/26/frog-1495034__340.jpg 1x, /static/uploads/photo/2016/07/03/16/26/frog-1495034_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 23
#                         <i class="icon icon_favorite"></i> 11
#                         <i class="icon icon_comment"></i> 33
#                     </div>
# <a href="/en/users/Couleur-1195798/">Couleur</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/roe-deer-kitz-wild-forest-red-deer-1482712/">
# <img alt="" src="/static/uploads/photo/2016/06/27/15/28/roe-deer-1482712__340.jpg" srcset="/static/uploads/photo/2016/06/27/15/28/roe-deer-1482712__340.jpg 1x, /static/uploads/photo/2016/06/27/15/28/roe-deer-1482712_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 16
#                         <i class="icon icon_favorite"></i> 9
#                         <i class="icon icon_comment"></i> 19
#                     </div>
# <a href="/en/users/Romi-19628/">Romi</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/architecture-media-harbour-1515475/">
# <img alt="" src="/static/uploads/photo/2016/07/13/20/44/architecture-1515475__340.jpg" srcset="/static/uploads/photo/2016/07/13/20/44/architecture-1515475__340.jpg 1x, /static/uploads/photo/2016/07/13/20/44/architecture-1515475_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 11
#                         <i class="icon icon_favorite"></i> 4
#                         <i class="icon icon_comment"></i> 10
#                     </div>
# <a href="/en/users/MichaelGaida-652234/">MichaelGaida</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/popcorn-cinema-ticket-film-1433327/">
# <img alt="" src="/static/uploads/photo/2016/06/03/12/42/popcorn-1433327__340.jpg" srcset="/static/uploads/photo/2016/06/03/12/42/popcorn-1433327__340.jpg 1x, /static/uploads/photo/2016/06/03/12/42/popcorn-1433327_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 8
#                         <i class="icon icon_favorite"></i> 9
#                         <i class="icon icon_comment"></i> 16
#                     </div>
# <a href="/en/users/annca-1564471/">annca</a>
# </div>
# </div>
# <div class="item" data-h="360" data-w="640">
# <a href="/en/flower-pink-pink-flowers-nature-1451676/">
# <img alt="" src="/static/uploads/photo/2016/06/12/10/01/flower-1451676__340.jpg"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 22
#                         <i class="icon icon_favorite"></i> 13
#                         <i class="icon icon_comment"></i> 3
#                     </div>
# <a href="/en/users/MikeBirdy-1860391/">MikeBirdy</a>
# </div>
# </div>
# <div class="item" data-h="428" data-w="640">
# <a href="/en/girl-water-wet-summer-female-1125318/">
# <img alt="" src="/static/uploads/photo/2016/01/07/04/25/girl-1125318__340.jpg" srcset="/static/uploads/photo/2016/01/07/04/25/girl-1125318__340.jpg 1x, /static/uploads/photo/2016/01/07/04/25/girl-1125318_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 36
#                         <i class="icon icon_favorite"></i> 40
#                         <i class="icon icon_comment"></i> 10
#                     </div>
# <a href="/en/users/Greyerbaby-2323/">Greyerbaby</a>
# </div>
# </div>
# <div class="item" data-h="472" data-w="640">
# <a href="/en/cat-animal-cat-portrait-cat-s-eyes-1508613/">
# <img alt="" src="/static/uploads/photo/2016/07/10/21/47/cat-1508613__340.jpg" srcset="/static/uploads/photo/2016/07/10/21/47/cat-1508613__340.jpg 1x, /static/uploads/photo/2016/07/10/21/47/cat-1508613_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 26
#                         <i class="icon icon_favorite"></i> 19
#                         <i class="icon icon_comment"></i> 22
#                     </div>
# <a href="/en/users/cocoparisienne-127419/">cocoparisienne</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/lost-places-factory-old-lapsed-1510592/">
# <img alt="" src="/static/uploads/photo/2016/07/11/20/34/lost-places-1510592__340.jpg" srcset="/static/uploads/photo/2016/07/11/20/34/lost-places-1510592__340.jpg 1x, /static/uploads/photo/2016/07/11/20/34/lost-places-1510592_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 16
#                         <i class="icon icon_favorite"></i> 19
#                         <i class="icon icon_comment"></i> 12
#                     </div>
# <a href="/en/users/MichaelGaida-652234/">MichaelGaida</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/seagull-bird-fly-animal-freedom-1511862/">
# <img alt="" src="/static/uploads/photo/2016/07/12/11/33/seagull-1511862__340.jpg" srcset="/static/uploads/photo/2016/07/12/11/33/seagull-1511862__340.jpg 1x, /static/uploads/photo/2016/07/12/11/33/seagull-1511862_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 16
#                         <i class="icon icon_favorite"></i> 11
#                         <i class="icon icon_comment"></i> 6
#                     </div>
# <a href="/en/users/2905102-2905102/">2905102</a>
# </div>
# </div>
# <div class="item" data-h="480" data-w="640">
# <a href="/en/beautiful-girl-smiling-da-young-1274056/">
# <img alt="" src="/static/uploads/photo/2016/03/23/04/01/beautiful-1274056__340.jpg" srcset="/static/uploads/photo/2016/03/23/04/01/beautiful-1274056__340.jpg 1x, /static/uploads/photo/2016/03/23/04/01/beautiful-1274056_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 64
#                         <i class="icon icon_favorite"></i> 53
#                         <i class="icon icon_comment"></i> 10
#                     </div>
# <a href="/en/users/DzeeShah-481870/">DzeeShah</a>
# </div>
# </div>
# <div class="item" data-h="375" data-w="640">
# <a href="/en/marigold-calendula-bud-open-1503876/">
# <img alt="" src="/static/uploads/photo/2016/07/08/09/32/marigold-1503876__340.jpg"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 35
#                         <i class="icon icon_favorite"></i> 11
#                         <i class="icon icon_comment"></i> 35
#                     </div>
# <a href="/en/users/Myriams-Fotos-1627417/">Myriams-Fotos</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/berries-blueberries-raspberries-1493905/">
# <img alt="" src="/static/uploads/photo/2016/07/02/22/42/berries-1493905__340.jpg" srcset="/static/uploads/photo/2016/07/02/22/42/berries-1493905__340.jpg 1x, /static/uploads/photo/2016/07/02/22/42/berries-1493905_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 20
#                         <i class="icon icon_favorite"></i> 10
#                         <i class="icon icon_comment"></i> 25
#                     </div>
# <a href="/en/users/Couleur-1195798/">Couleur</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/sunset-sun-abendstimmung-1365830/">
# <img alt="" src="/static/uploads/photo/2016/05/01/20/41/sunset-1365830__340.jpg" srcset="/static/uploads/photo/2016/05/01/20/41/sunset-1365830__340.jpg 1x, /static/uploads/photo/2016/05/01/20/41/sunset-1365830_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 15
#                         <i class="icon icon_favorite"></i> 16
#                         <i class="icon icon_comment"></i> 18
#                     </div>
# <a href="/en/users/Myriams-Fotos-1627417/">Myriams-Fotos</a>
# </div>
# </div>
# <div class="item" data-h="407" data-w="640">
# <a href="/en/water-drink-detox-detox-water-1487304/">
# <img alt="" src="/static/uploads/photo/2016/06/29/17/14/water-1487304__340.jpg" srcset="/static/uploads/photo/2016/06/29/17/14/water-1487304__340.jpg 1x, /static/uploads/photo/2016/06/29/17/14/water-1487304_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 39
#                         <i class="icon icon_favorite"></i> 17
#                         <i class="icon icon_comment"></i> 30
#                     </div>
# <a href="/en/users/condesign-509903/">condesign</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/heart-rhinestones-sand-beach-ocean-1407248/">
# <img alt="" src="/static/uploads/photo/2016/05/21/19/06/heart-1407248__340.jpg" srcset="/static/uploads/photo/2016/05/21/19/06/heart-1407248__340.jpg 1x, /static/uploads/photo/2016/05/21/19/06/heart-1407248_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 18
#                         <i class="icon icon_favorite"></i> 10
#                         <i class="icon icon_comment"></i> 9
#                     </div>
# <a href="/en/users/diego_torres-1118992/">diego_torres</a>
# </div>
# </div>
# <div class="item" data-h="480" data-w="640">
# <a href="/en/dandelion-flower-meadow-1432019/">
# <img alt="" src="/static/uploads/photo/2016/06/02/20/24/dandelion-1432019__340.jpg" srcset="/static/uploads/photo/2016/06/02/20/24/dandelion-1432019__340.jpg 1x, /static/uploads/photo/2016/06/02/20/24/dandelion-1432019_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 22
#                         <i class="icon icon_favorite"></i> 11
#                         <i class="icon icon_comment"></i> 16
#                     </div>
# <a href="/en/users/MichaelGaida-652234/">MichaelGaida</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/bluebells-campanula-portenschlagiana-1429817/">
# <img alt="" src="/static/uploads/photo/2016/06/01/22/02/bluebells-1429817__340.jpg" srcset="/static/uploads/photo/2016/06/01/22/02/bluebells-1429817__340.jpg 1x, /static/uploads/photo/2016/06/01/22/02/bluebells-1429817_640.jpg 2x"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 13
#                         <i class="icon icon_favorite"></i> 10
#                         <i class="icon icon_comment"></i> 11
#                     </div>
# <a href="/en/users/nachar-59978/">nachar</a>
# </div>
# </div>
# <div class="item" data-h="337" data-w="640">
# <a href="/en/lighter-flame-burn-kindle-light-1363095/">
# <img alt="" data-lazy="/static/uploads/photo/2016/04/30/15/11/lighter-1363095__340.jpg" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 20
#                         <i class="icon icon_favorite"></i> 19
#                         <i class="icon icon_comment"></i> 8
#                     </div>
# <a href="/en/users/Comfreak-51581/">Comfreak</a>
# </div>
# </div>
# <div class="item" data-h="480" data-w="640">
# <a href="/en/water-lily-pond-lily-pad-green-1364465/">
# <img alt="" data-lazy="/static/uploads/photo/2016/05/01/05/55/water-lily-1364465__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/05/01/05/55/water-lily-1364465__340.jpg 1x, /static/uploads/photo/2016/05/01/05/55/water-lily-1364465_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 19
#                         <i class="icon icon_favorite"></i> 7
#                         <i class="icon icon_comment"></i> 5
#                     </div>
# <a href="/en/users/JoBeeOneToo-55990/">JoBeeOneToo</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/dock-lake-finland-dark-evening-1365387/">
# <img alt="" data-lazy="/static/uploads/photo/2016/05/01/17/58/dock-1365387__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/05/01/17/58/dock-1365387__340.jpg 1x, /static/uploads/photo/2016/05/01/17/58/dock-1365387_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 22
#                         <i class="icon icon_favorite"></i> 18
#                         <i class="icon icon_comment"></i> 7
#                     </div>
# <a href="/en/users/kerttu-569708/">kerttu</a>
# </div>
# </div>
# <div class="item" data-h="480" data-w="640">
# <a href="/en/champagne-drink-sparkling-wine-1500248/">
# <img alt="" data-lazy="/static/uploads/photo/2016/07/06/09/47/champagne-1500248__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/07/06/09/47/champagne-1500248__340.jpg 1x, /static/uploads/photo/2016/07/06/09/47/champagne-1500248_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 19
#                         <i class="icon icon_favorite"></i> 12
#                         <i class="icon icon_comment"></i> 16
#                     </div>
# <a href="/en/users/Gellinger-201217/">Gellinger</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/clouds-clouds-form-cloud-mountain-1439324/">
# <img alt="" data-lazy="/static/uploads/photo/2016/06/06/12/33/clouds-1439324__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/06/06/12/33/clouds-1439324__340.jpg 1x, /static/uploads/photo/2016/06/06/12/33/clouds-1439324_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 19
#                         <i class="icon icon_favorite"></i> 11
#                         <i class="icon icon_comment"></i> 9
#                     </div>
# <a href="/en/users/WolfBlur-2503887/">WolfBlur</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/girl-roses-red-wreath-flowers-1403425/">
# <img alt="" data-lazy="/static/uploads/photo/2016/05/19/17/09/girl-1403425__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/05/19/17/09/girl-1403425__340.jpg 1x, /static/uploads/photo/2016/05/19/17/09/girl-1403425_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 16
#                         <i class="icon icon_favorite"></i> 12
#                         <i class="icon icon_comment"></i> 3
#                     </div>
# <a href="/en/users/AdinaVoicu-485024/">AdinaVoicu</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/kid-children-baby-kiddie-summer-1365105/">
# <img alt="" data-lazy="/static/uploads/photo/2016/05/01/15/36/kid-1365105__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/05/01/15/36/kid-1365105__340.jpg 1x, /static/uploads/photo/2016/05/01/15/36/kid-1365105_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 13
#                         <i class="icon icon_favorite"></i> 13
#                         <i class="icon icon_comment"></i> 5
#                     </div>
# <a href="/en/users/MiguelRPerez-131821/">MiguelRPerez</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/lake-scenery-finland-spring-evening-1365288/">
# <img alt="" data-lazy="/static/uploads/photo/2016/05/01/17/24/lake-scenery-1365288__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/05/01/17/24/lake-scenery-1365288__340.jpg 1x, /static/uploads/photo/2016/05/01/17/24/lake-scenery-1365288_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 15
#                         <i class="icon icon_favorite"></i> 12
#                         <i class="icon icon_comment"></i> 8
#                     </div>
# <a href="/en/users/kerttu-569708/">kerttu</a>
# </div>
# </div>
# <div class="item" data-h="427" data-w="640">
# <a href="/en/sunset-wadden-sea-art-north-sea-1393764/">
# <img alt="" data-lazy="/static/uploads/photo/2016/05/15/14/15/sunset-1393764__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/05/15/14/15/sunset-1393764__340.jpg 1x, /static/uploads/photo/2016/05/15/14/15/sunset-1393764_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 12
#                         <i class="icon icon_favorite"></i> 3
#                         <i class="icon icon_comment"></i> 6
#                     </div>
# <a href="/en/users/WolfBlur-2503887/">WolfBlur</a>
# </div>
# </div>
# <div class="item" data-h="480" data-w="640">
# <a href="/en/heart-wood-logs-1288420/">
# <img alt="" data-lazy="/static/uploads/photo/2016/03/29/14/48/heart-1288420__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/03/29/14/48/heart-1288420__340.jpg 1x, /static/uploads/photo/2016/03/29/14/48/heart-1288420_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 41
#                         <i class="icon icon_favorite"></i> 32
#                         <i class="icon icon_comment"></i> 20
#                     </div>
# <a href="/en/users/nachar-59978/">nachar</a>
# </div>
# </div>
# <div class="item" data-h="426" data-w="640">
# <a href="/en/mountain-lake-landscape-nature-1504197/">
# <img alt="" data-lazy="/static/uploads/photo/2016/07/08/12/19/mountain-1504197__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/07/08/12/19/mountain-1504197__340.jpg 1x, /static/uploads/photo/2016/07/08/12/19/mountain-1504197_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 19
#                         <i class="icon icon_favorite"></i> 15
#                         <i class="icon icon_comment"></i> 11
#                     </div>
# <a href="/en/users/bykst-86169/">bykst</a>
# </div>
# </div>
# <div class="item" data-h="640" data-w="480">
# <a href="/en/beautiful-girl-smiling-da-young-1274055/">
# <img alt="" data-lazy="/static/uploads/photo/2016/03/23/04/00/beautiful-1274055__340.jpg" data-lazy-srcset="/static/uploads/photo/2016/03/23/04/00/beautiful-1274055__340.jpg 1x, /static/uploads/photo/2016/03/23/04/00/beautiful-1274055_640.jpg 2x" src="/static/img/blank.gif"/>
# </a>
# <div>
# <div class="counts hide-xs hide-sm">
# <i class="icon icon_like"></i> 15
#                         <i class="icon icon_favorite"></i> 22
#                         <i class="icon icon_comment"></i> 3
#                     </div>
# <a href="/en/users/DzeeShah-481870/">DzeeShah</a>
# </div>
# </div>
# </div>
# <div style="margin:25px auto 0;text-align:center">
# <a class="pure-button button-green" href="/en/editors_choice/">Discover more</a>
# </div></div></div>
# <div style="padding:0 20px">
# <h2 style="margin:80px 0 30px">
# <span class="hide-xs hide-sm">Browse stock photos by category</span>
# <span class="hide-md hide-lg hide-xl">Browse by category</span>
# </h2>
# <div class="cats pure-g hover_links">
# <div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=animals">Animals</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=buildings">Architecture/Buildings</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=backgrounds">Backgrounds/Textures</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=fashion">Beauty/Fashion</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=business">Business/Finance</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=computer">Computer/Communication</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=education">Education</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=feelings">Emotions</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=food">Food/Drink</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=health">Health/Medical</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=industry">Industry/Craft</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=music">Music</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=nature">Nature/Landscapes</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=people">People</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=places">Places/Monuments</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=religion">Religion</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=science">Science/Technology</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=sports">Sports</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=transportation">Transportation/Traffic</a></div><div class="pure-u-1 pure-u-sm-1-2 pure-u-md-1-3 pure-u-lg-1-4 pure-u-xl-1-5"><a href="/en/photos/?cat=travel">Travel/Vacation</a></div>
# </div>
# </div>
# <div style="position:relative;top:55px;text-align:center;margin-top:30px;padding:40px 20px;background:#f7f8fa">
# <h2>Join Pixabay</h2>
# <p style="max-width:640px;margin:0 auto 30px">Download royalty free stock photos and videos and share your own pictures as public domain with people all over the world.</p>
# <a class="pure-button button-green" href="/en/accounts/register/">Sign up, it's free!</a>
# </div>
# </div>
# </div>
# <div id="push"></div>
# </div>
# <div id="footer">
# <div id="footer_inner">
# <div class="hover_links hide-xs hide-sm" style="float:right;margin:2px 0 0 30px">
# <a href="https://www.facebook.com/pixabay" target="_blank"><i class="icon icon_facebook"></i></a>
# <a href="https://twitter.com/pixabay" target="_blank"><i class="icon icon_twitter"></i></a>
# <a href="https://plus.google.com/+Pixabay" target="_blank"><i class="icon icon_google_plus"></i></a>
# </div>
# <span style="margin-right:30px">© 2016 Pixabay</span>
# <a class="dd_box menu hide-xs hide-sm hide-md" style="margin-right:30px">Free Images <i class="arrow"></i></a>
# <div>
# <a href="/en/photos/?image_type=photo">Free photos</a>
# <a href="/en/photos/?image_type=vector">Free vector graphics</a>
# <a href="/en/photos/?image_type=illustration">Free illustrations</a>
# <a href="/en/videos/list/">Free Videos</a>
# </div>
# <a class="dd_box menu langs" style="margin-right:30px">Language <i class="arrow"></i></a>
# <div><a href="/cs/">Čeština</a><a href="/da/">Dansk</a><a href="/de/">Deutsch</a><a href="/en/">English</a><a href="/es/">Español</a><a href="/fr/">Français</a><a href="/id/">Indonesia</a><a href="/it/">Italiano</a><a href="/hu/">Magyar</a><a href="/nl/">Nederlands</a><a href="/no/">Norsk</a><a href="/pl/">Polski</a><a href="/pt/">Português</a><a href="/ro/">Română</a><a href="/sk/">Slovenčina</a><a href="/fi/">Suomi</a><a href="/sv/">Svenska</a><a href="/tr/">Türkçe</a><a href="/vi/">Việt</a><a href="/th/">ไทย</a><a href="/bg/">Български</a><a href="/ru/">Русский</a><a href="/el/">Ελληνική</a><a href="/ja/">日本語</a><a href="/ko/">한국어</a><a href="/zh/">简体中文</a></div>
# <a class="dd_box menu" style="margin-right:30px">Service <i class="arrow"></i></a>
# <div style="min-width:80px">
# <a href="/en/blog/">Blog</a>
# <a href="/en/forum/">Forum</a>
# <a href="/en/service/about/">About Us</a>
# <a href="/en/service/privacy/">Privacy Policy</a>
# </div>
# <a href="/api/docs/" style="margin-right:30px">API</a>
# <a href="/en/service/faq/" style="margin-right:30px">FAQ</a>
# <a href="/en/service/terms/">Terms</a>
# </div>
# </div>
# <div id="fb-root"></div><a id="toTop">▲</a>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
# <script>
#     window.jQuery || document.write('<script src="/static/js/jquery.js"><\/script>');
#     var LANG = 'en', I18N_DELETE = 'Really delete?';
# </script>
# <script src="/static/js/base39.min.js"></script>
# <script>
#         $('.flex_grid').flexImages({ rowHeight: 320, maxRows: 8, truncate: true });
#         $('[data-lazy]').unveil(400);
#         resized();
#         $('#hero').css('backgroundImage', ww > 1440 && 'url(/static/uploads/index/2016/07/13/17-03-22-847_1920x430.jpg)' || ww > 640 && 'url(/static/uploads/index/2016/07/13/17-03-22-847_1440x480.jpg)' || 'url(/static/uploads/photo/2015/04/08/15/09/daisy-712892_640.jpg)');
#         if (ww > 567) document.write('<script src="//apis.google.com/js/platform.js" async defer><\/script><script src="//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.5&appId=114593902037957" async defer><\/script><script src="//platform.twitter.com/widgets.js" async defer><\/script>');
#     </script>
# <script type="application/ld+json">{
#         "@context": "http://schema.org", "@type": "WebSite", "url": "https://pixabay.com/",
#         "name": "Pixabay", "sameAs" : ["https://www.facebook.com/pixabay", "https://twitter.com/pixabay", "https://plus.google.com/+Pixabay"],
#         "potentialAction": { "@type": "SearchAction", "target": "https://pixabay.com/photos/?q={q}", "query-input": "required name=q" }
#     }</script>
# </body>
# </html>
# C:\Users\hp\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
img_list = dom.select('#gallery > div > div.item > a > img')

# %%
img_list[0]
# Out:
# <img alt="" src="/static/uploads/photo/2016/03/05/20/05/alcohol-1238646__340.jpg" srcset="/static/uploads/photo/2016/03/05/20/05/alcohol-1238646__340.jpg 1x, /static/uploads/photo/2016/03/05/20/05/alcohol-1238646_640.jpg 2x"/>

# %%
img_addr_0 = "https://pixabay.com" + img_list[0]['src']

# %%
print (img_addr)
# Out:
# https://pixabay.com/static/uploads/photo/2016/03/05/20/05/alcohol-1238646__340.jpg

# %%
img_name_0 = img_list[0]['src'].split('/')[-1]

# %%
print (img_name)
# Out:
# alcohol-1238646__340.jpg

# %%
for i in range(len(img_list)):
    image_url = "https://pixabay.com" + img_list[i]['src']
    filename = image_name = img_list[i]['src'].split('/')[-1]
 
    download_image(image_url, filename)

# %%
print (res)
# Out:
# <Response [200]>

# %%
# pixabay.com에서 이미지 크롤링해오기
def crawl_image():
    res = requests.get('https://pixabay.com/en/')
    
    if res.status_code == 200:
        soup = bs(res.text)
        images = soup.select('#gallery > div.flex_grid.credits > div > a > img')
        print (len(images))
        
        for image in images:
            # 속성 출력하기
            print (image.attrs)
            
            # 속성 중 이미지 src 가져와서 이미지 full url을 만듭니다.
            image_url = "https://pixabay.com" + image.attrs['src']
            filename = image_url.split('/')[-1]
            
            print (image_url, filename)
            
            # 로컬 컴퓨터에 이미지 다운로드 받기
            download_image(image_url, filename)   

crawl_image()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# 32
# {'alt': '', 'src': '/static/uploads/photo/2016/03/05/20/05/alcohol-1238646__340.jpg', 'srcset': '/static/uploads/photo/2016/03/05/20/05/alcohol-1238646__340.jpg 1x, /static/uploads/photo/2016/03/05/20/05/alcohol-1238646_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/03/05/20/05/alcohol-1238646__340.jpg alcohol-1238646__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/07/16/46/roll-the-dice-1502706__340.jpg', 'srcset': '/static/uploads/photo/2016/07/07/16/46/roll-the-dice-1502706__340.jpg 1x, /static/uploads/photo/2016/07/07/16/46/roll-the-dice-1502706_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/07/07/16/46/roll-the-dice-1502706__340.jpg roll-the-dice-1502706__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/05/16/53/leaf-1498985__340.jpg'}
# https://pixabay.com/static/uploads/photo/2016/07/05/16/53/leaf-1498985__340.jpg leaf-1498985__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/03/16/26/frog-1495034__340.jpg', 'srcset': '/static/uploads/photo/2016/07/03/16/26/frog-1495034__340.jpg 1x, /static/uploads/photo/2016/07/03/16/26/frog-1495034_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/07/03/16/26/frog-1495034__340.jpg frog-1495034__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/06/27/15/28/roe-deer-1482712__340.jpg', 'srcset': '/static/uploads/photo/2016/06/27/15/28/roe-deer-1482712__340.jpg 1x, /static/uploads/photo/2016/06/27/15/28/roe-deer-1482712_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/06/27/15/28/roe-deer-1482712__340.jpg roe-deer-1482712__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/13/20/44/architecture-1515475__340.jpg', 'srcset': '/static/uploads/photo/2016/07/13/20/44/architecture-1515475__340.jpg 1x, /static/uploads/photo/2016/07/13/20/44/architecture-1515475_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/07/13/20/44/architecture-1515475__340.jpg architecture-1515475__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/06/03/12/42/popcorn-1433327__340.jpg', 'srcset': '/static/uploads/photo/2016/06/03/12/42/popcorn-1433327__340.jpg 1x, /static/uploads/photo/2016/06/03/12/42/popcorn-1433327_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/06/03/12/42/popcorn-1433327__340.jpg popcorn-1433327__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/06/12/10/01/flower-1451676__340.jpg'}
# https://pixabay.com/static/uploads/photo/2016/06/12/10/01/flower-1451676__340.jpg flower-1451676__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/01/07/04/25/girl-1125318__340.jpg', 'srcset': '/static/uploads/photo/2016/01/07/04/25/girl-1125318__340.jpg 1x, /static/uploads/photo/2016/01/07/04/25/girl-1125318_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/01/07/04/25/girl-1125318__340.jpg girl-1125318__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/10/21/47/cat-1508613__340.jpg', 'srcset': '/static/uploads/photo/2016/07/10/21/47/cat-1508613__340.jpg 1x, /static/uploads/photo/2016/07/10/21/47/cat-1508613_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/07/10/21/47/cat-1508613__340.jpg cat-1508613__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/11/20/34/lost-places-1510592__340.jpg', 'srcset': '/static/uploads/photo/2016/07/11/20/34/lost-places-1510592__340.jpg 1x, /static/uploads/photo/2016/07/11/20/34/lost-places-1510592_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/07/11/20/34/lost-places-1510592__340.jpg lost-places-1510592__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/12/11/33/seagull-1511862__340.jpg', 'srcset': '/static/uploads/photo/2016/07/12/11/33/seagull-1511862__340.jpg 1x, /static/uploads/photo/2016/07/12/11/33/seagull-1511862_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/07/12/11/33/seagull-1511862__340.jpg seagull-1511862__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/03/23/04/01/beautiful-1274056__340.jpg', 'srcset': '/static/uploads/photo/2016/03/23/04/01/beautiful-1274056__340.jpg 1x, /static/uploads/photo/2016/03/23/04/01/beautiful-1274056_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/03/23/04/01/beautiful-1274056__340.jpg beautiful-1274056__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/08/09/32/marigold-1503876__340.jpg'}
# https://pixabay.com/static/uploads/photo/2016/07/08/09/32/marigold-1503876__340.jpg marigold-1503876__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/07/02/22/42/berries-1493905__340.jpg', 'srcset': '/static/uploads/photo/2016/07/02/22/42/berries-1493905__340.jpg 1x, /static/uploads/photo/2016/07/02/22/42/berries-1493905_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/07/02/22/42/berries-1493905__340.jpg berries-1493905__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/05/01/20/41/sunset-1365830__340.jpg', 'srcset': '/static/uploads/photo/2016/05/01/20/41/sunset-1365830__340.jpg 1x, /static/uploads/photo/2016/05/01/20/41/sunset-1365830_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/05/01/20/41/sunset-1365830__340.jpg sunset-1365830__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/06/29/17/14/water-1487304__340.jpg', 'srcset': '/static/uploads/photo/2016/06/29/17/14/water-1487304__340.jpg 1x, /static/uploads/photo/2016/06/29/17/14/water-1487304_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/06/29/17/14/water-1487304__340.jpg water-1487304__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/05/21/19/06/heart-1407248__340.jpg', 'srcset': '/static/uploads/photo/2016/05/21/19/06/heart-1407248__340.jpg 1x, /static/uploads/photo/2016/05/21/19/06/heart-1407248_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/05/21/19/06/heart-1407248__340.jpg heart-1407248__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/06/02/20/24/dandelion-1432019__340.jpg', 'srcset': '/static/uploads/photo/2016/06/02/20/24/dandelion-1432019__340.jpg 1x, /static/uploads/photo/2016/06/02/20/24/dandelion-1432019_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/06/02/20/24/dandelion-1432019__340.jpg dandelion-1432019__340.jpg
# {'alt': '', 'src': '/static/uploads/photo/2016/06/01/22/02/bluebells-1429817__340.jpg', 'srcset': '/static/uploads/photo/2016/06/01/22/02/bluebells-1429817__340.jpg 1x, /static/uploads/photo/2016/06/01/22/02/bluebells-1429817_640.jpg 2x'}
# https://pixabay.com/static/uploads/photo/2016/06/01/22/02/bluebells-1429817__340.jpg bluebells-1429817__340.jpg
# {'src': '/static/img/blank.gif', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/04/30/15/11/lighter-1363095__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/05/01/05/55/water-lily-1364465__340.jpg 1x, /static/uploads/photo/2016/05/01/05/55/water-lily-1364465_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/05/01/05/55/water-lily-1364465__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/05/01/17/58/dock-1365387__340.jpg 1x, /static/uploads/photo/2016/05/01/17/58/dock-1365387_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/05/01/17/58/dock-1365387__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/07/06/09/47/champagne-1500248__340.jpg 1x, /static/uploads/photo/2016/07/06/09/47/champagne-1500248_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/07/06/09/47/champagne-1500248__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/06/06/12/33/clouds-1439324__340.jpg 1x, /static/uploads/photo/2016/06/06/12/33/clouds-1439324_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/06/06/12/33/clouds-1439324__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/05/19/17/09/girl-1403425__340.jpg 1x, /static/uploads/photo/2016/05/19/17/09/girl-1403425_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/05/19/17/09/girl-1403425__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/05/01/15/36/kid-1365105__340.jpg 1x, /static/uploads/photo/2016/05/01/15/36/kid-1365105_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/05/01/15/36/kid-1365105__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/05/01/17/24/lake-scenery-1365288__340.jpg 1x, /static/uploads/photo/2016/05/01/17/24/lake-scenery-1365288_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/05/01/17/24/lake-scenery-1365288__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/05/15/14/15/sunset-1393764__340.jpg 1x, /static/uploads/photo/2016/05/15/14/15/sunset-1393764_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/05/15/14/15/sunset-1393764__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/03/29/14/48/heart-1288420__340.jpg 1x, /static/uploads/photo/2016/03/29/14/48/heart-1288420_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/03/29/14/48/heart-1288420__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/07/08/12/19/mountain-1504197__340.jpg 1x, /static/uploads/photo/2016/07/08/12/19/mountain-1504197_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/07/08/12/19/mountain-1504197__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif
# {'src': '/static/img/blank.gif', 'data-lazy-srcset': '/static/uploads/photo/2016/03/23/04/00/beautiful-1274055__340.jpg 1x, /static/uploads/photo/2016/03/23/04/00/beautiful-1274055_640.jpg 2x', 'alt': '', 'data-lazy': '/static/uploads/photo/2016/03/23/04/00/beautiful-1274055__340.jpg'}
# https://pixabay.com/static/img/blank.gif blank.gif

# %% [markdown]
# ## imdb에서 영화 정보 크롤링해보기
#
# 타겟 URL: http://www.imdb.com/movies-coming-soon/2016-01/
#
# 이곳에 들어가면 영화 제목, 장르, 평점, 감독, 배우 등의 정보가 있습니다. URL도 2015-01, 2015-02.. 이런식으로 바꿀 수 있습니다. 우선 2016-01 영화 정보를 함께 크롤링해봅시다.

# %%
import requests
from bs4 import BeautifulSoup
import urllib.request

# %%
response = requests.get('http://www.imdb.com/movies-coming-soon/2016-01/')
#  response.text
dom = BeautifulSoup(response.text)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
movie_list = dom.select('.list_item')
print (len(movie_list))
type(movie_list)
# Out:
# 32
# list

# %%
ms_0 = movie_list[0]

# %%
mtitle = ms_0.select('.overview-top > h4 > a ')
title = mtitle[0].text
print (title)

img = ms_0.select('img')

img_url = img[0].attrs['src']
imgname = img_url.split('/')[-1]

res = urllib.request.urlretrieve(img_url, imgname)
print (imgname)

duration = ms_0.select('time')[0].text
print (duration)


genre_list = ms_0.find_all('span', {'itemprop' : 'genre'})
genre = []
for i in range(len(genre_list)):
    genre.append( genre_list[i].text)
print (genre)

rating = ms_0.select('div.metascore.no_ratings > strong')[0].text
print (rating)

director = ms_0.find_all('span', {'itemprop': 'director'})[0].select('a')[0].text
# director = director_h.select('a')[0].text
print (director)

actors = []
for i in range(len(ms_0.find_all('span', {'itemprop': 'actors'}))):
    actors.append(ms_0.find_all('span', {'itemprop': 'actors'})[i].select('a')[0].text)
    # director = director_h.select('a')[0].text
print (actors)
# Out:
#  The Hateful Eight (2015)
# MV5BMjA1MTc1NTg5NV5BMl5BanBnXkFtZTgwOTM2MDEzNzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 187 min
# ['Crime', 'Drama', 'Mystery', 'Thriller', 'Western']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Kurt Russell', 'Jennifer Jason Leigh', 'Walton Goggins']

# %%
for i in range(len(movie_list)):
    mtitle = movie_list[i].select('.overview-top > h4 > a ')
    title = mtitle[0].text
    print (title)

    img = movie_list[i].select('img')
    img_url = img[0].attrs['src']
    imgname = img_url.split('/')[-1]
    res = urllib.request.urlretrieve(img_url, imgname)
    print (imgname)

    duration = movie_list[i].select('time')[0].text
    print (duration)


    genre_list = movie_list[i].find_all('span', {'itemprop' : 'genre'})
    genre = []
    for i in range(len(genre_list)):
        genre.append( genre_list[i].text)
    print (genre)

    rating = movie_list[i].select('div.metascore.no_ratings > strong')[0].text
    print (rating)

    director = movie_list[i].find_all('span', {'itemprop': 'director'})[0].select('a')[0].text
    # director = director_h.select('a')[0].text
    print (director)

    actors = []
    for i in range(len(movie_list[i].find_all('span', {'itemprop': 'actors'}))):
        actors.append(movie_list[i].find_all('span', {'itemprop': 'actors'})[i].select('a')[0].text)
        # director = director_h.select('a')[0].text
    print (actors)
    print ("  ")
    print ("   -------------------  ")
    print ("  ")
# Out:
#  The Hateful Eight (2015)
# MV5BMjA1MTc1NTg5NV5BMl5BanBnXkFtZTgwOTM2MDEzNzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 187 min
# ['Crime', 'Drama', 'Mystery', 'Thriller', 'Western']
# 88
# Duke Johnson
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt']
#
#    -------------------
#
#  Anomalisa (2015)
# MV5BMTkyMzI2MzQ1N15BMl5BanBnXkFtZTgwNDg0MzQxNzE@._V1_UY209_CR1,0,140,209_AL_.jpg
# 90 min
# ['Animation', 'Comedy', 'Drama', 'Romance']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  The Forest (2016)
# MV5BMjAwMzQzNTc5OV5BMl5BanBnXkFtZTgwNDgyMTU2NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 93 min
# ['Horror', 'Mystery', 'Thriller']
# 34
# Jason Zada
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  The Revenant (2015)
# MV5BMjU4NDExNDM1NF5BMl5BanBnXkFtZTgwMDIyMTgxNzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 156 min
# ['Adventure', 'Drama', 'Thriller', 'Western']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Anomalisa (2015)
# MV5BMTkyMzI2MzQ1N15BMl5BanBnXkFtZTgwNDg0MzQxNzE@._V1_UY209_CR1,0,140,209_AL_.jpg
# 90 min
# ['Animation', 'Comedy', 'Drama', 'Romance']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  The Masked Saint (2016)
# MV5BMjI0NzU4MjkxNl5BMl5BanBnXkFtZTgwMTYxMTA1NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 105 min
# ['Action', 'Biography', 'Crime', 'Drama', 'Family', 'Fantasy']
# 22
# Warren P. Sonoda
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Wazir (2016)
# MV5BMTUzNDU4NDMyOV5BMl5BanBnXkFtZTgwNjcyNzU0NzE@._V1_UY209_CR8,0,140,209_AL_.jpg
# 103 min
# ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller']
# 88
# Duke Johnson
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt']
#
#    -------------------
#
#  Anesthesia (2015)
# MV5BNDUyMjgxNzQ4NV5BMl5BanBnXkFtZTgwNzkzMDA1NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 90 min
# ['Drama', 'Thriller']
# 88
# Duke Johnson
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt']
#
#    -------------------
#
#  Comoara (2015)
# MV5BMTUzNjIyOTU1Ml5BMl5BanBnXkFtZTgwMjEzNzI2NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 89 min
# ['Comedy']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Lamb (2015)
# MV5BMjM5NDU0MzA0OV5BMl5BanBnXkFtZTgwMTE3MDgyNzE@._V1_UY209_CR1,0,140,209_AL_.jpg
# 97 min
# ['Drama']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Yosemite (2015)
# MV5BMjA5Njg3NTE5OV5BMl5BanBnXkFtZTgwMjk1NzQ5NjE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 80 min
# ['Drama']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Ride Along 2 (2016)
# MV5BMTU4ODAzMzcxOV5BMl5BanBnXkFtZTgwODkxMDI1NjE@._V1_UX140_CR0,0,140,209_AL_.jpg
# 102 min
# ['Action', 'Comedy']
# 88
# Duke Johnson
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt']
#
#    -------------------
#
#  13 Hours (2016)
# MV5BMjU3OTQ5NDc3Ml5BMl5BanBnXkFtZTgwOTEwNTkxNzE@._V1_UX140_CR0,0,140,209_AL_.jpg
# 144 min
# ['Action', 'Drama', 'Thriller', 'War']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Norm of the North (2016)
# MV5BNTY4MDk4Mjc4NV5BMl5BanBnXkFtZTgwNzg4OTk0NzE@._V1_UX140_CR0,0,140,209_AL_.jpg
# 90 min
# ['Animation', 'Adventure', 'Comedy', 'Family']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Band of Robbers (2015)
# MV5BMTczNTE3ODc0NF5BMl5BanBnXkFtZTgwODU1MDQyNzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 95 min
# ['Adventure', 'Comedy', 'Crime', 'Thriller']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  The Benefactor (2015)
# MV5BMTgyMTMyMjQ0MV5BMl5BanBnXkFtZTgwMDQxNTE3NzE@._V1_UY209_CR1,0,140,209_AL_.jpg
# 93 min
# ['Drama']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Moonwalkers (2015)
# MV5BMjQyNzU4MjMyNF5BMl5BanBnXkFtZTgwMDQ0NzQ0NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 107 min
# ['Comedy']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  A Perfect Day (2015)
# MV5BMTUwNjgzOTQ4OV5BMl5BanBnXkFtZTgwMjA5OTM2NTE@._V1_UY209_CR3,0,140,209_AL_.jpg
# 106 min
# ['Comedy', 'Drama', 'War']
# 34
# Jason Zada
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Dirty Grandpa (2016)
# MV5BMzk0NzkyNDk2M15BMl5BanBnXkFtZTgwNDczOTU3NzE@._V1_UX140_CR0,0,140,209_AL_.jpg
# 102 min
# ['Comedy']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  The 5th Wave (2016)
# MV5BMjQwOTc0Mzg3Nl5BMl5BanBnXkFtZTgwOTg3NjI2NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 112 min
# ['Action', 'Adventure', 'Sci-Fi', 'Thriller']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  The Boy (2016)
# MV5BMTc1MjcxNzcwMV5BMl5BanBnXkFtZTgwMTE0NTE2NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 97 min
# ['Horror', 'Mystery', 'Thriller']
# 34
# Jason Zada
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Yip Man 3 (2015)
# MV5BMTkxNzc0MjgwN15BMl5BanBnXkFtZTgwMzY3Nzk1NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 105 min
# ['Action', 'Biography', 'Drama', 'History']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Synchronicity (2015)
# MV5BMTc2NDAyOTc4MV5BMl5BanBnXkFtZTgwNjE4Mjk0NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 101 min
# ['Mystery', 'Sci-Fi', 'Thriller']
# 34
# Jason Zada
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Monster Hunt (2015)
# MV5BMTUyMjUzNDgxMV5BMl5BanBnXkFtZTgwMDUwNTQ2NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 117 min
# ['Action', 'Comedy', 'Fantasy']
# 34
# Jason Zada
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Mojave (2015)
# MV5BMjM1OTE1OTUwN15BMl5BanBnXkFtZTgwMjA3NTkzNzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 93 min
# ['Thriller']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Aferim! (2015)
# MV5BNTgxNjA5MDkzNF5BMl5BanBnXkFtZTgwMTUyNzA5NDE@._V1_UY209_CR3,0,140,209_AL_.jpg
# 108 min
# ['Adventure', 'Comedy', 'Drama', 'History', 'Western']
# 88
# Duke Johnson
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt']
#
#    -------------------
#
#  Exposed (2016)
# MV5BMjAwMzk1MDI1OF5BMl5BanBnXkFtZTgwMDYxODkzNzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 102 min
# ['Crime', 'Drama', 'Mystery', 'Thriller']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Kung Fu Panda 3 (2016)
# MV5BMTUyNzgxNjg2M15BMl5BanBnXkFtZTgwMTY1NDI1NjE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 95 min
# ['Animation', 'Action', 'Adventure', 'Comedy', 'Family']
# 88
# Duke Johnson
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt']
#
#    -------------------
#
#  The Finest Hours (2016)
# MV5BNTY1MDU1NzYzN15BMl5BanBnXkFtZTgwOTA0MDQyNzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 117 min
# ['Action', 'Drama', 'History', 'Thriller']
# 76
# Alejandro G. Iñárritu
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Fifty Shades of Black (2016)
# MV5BMTQ3MTg3MzY4OV5BMl5BanBnXkFtZTgwNTI4MzM1NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 92 min
# ['Comedy']
# 68
# Quentin Tarantino
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Jane Got a Gun (2016)
# MV5BMTgwNDk0NDkwMl5BMl5BanBnXkFtZTgwNzYyNjA3NzE@._V1_UY209_CR0,0,140,209_AL_.jpg
# 98 min
# ['Action', 'Drama', 'Western']
# 34
# Jason Zada
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------
#
#  Saala Khadoos (2016)
# MV5BM2Q5YmM3YjMtOTE2Mi00MDg5LThkZjctYzUxOWU2ZTM1ZDk4XkEyXkFqcGdeQXVyMTExNDQ2MTI@._V1_UY209_CR8,0,140,209_AL_.jpg
# 109 min
# ['Action', 'Drama', 'Sport']
# 34
# Jason Zada
# ['Samuel L. Jackson', 'Jennifer Jason Leigh', 'Stephanie Vogt', 'Domhnall Gleeson']
#
#    -------------------

# %%
import requests
from bs4 import BeautifulSoup as bs
import urllib.request

# 2015-01 ~ 2015-12까지 순회하며 크롤링을 할 것이므로, url 파라미터를 받는 함수를 만듭니다.
def movie_crawler(url):
    res = requests.get(url)

    # 예상치 못하게 404나 500을 받았는데, html을 파싱하려고 하면
    # 에러가 발생하므로, 200(성공)일때만 코드가 실행되도록 합니다.
    if res.status_code == 200:
        soup = bs(res.text)

        #
        # titles = soup.select('#main > div > div.list.detail > div > table > tbody > tr > td.overview-top > h4 > a')
        # images = soup.select('#img_primary > div > a > div > img')
        #
        # 이렇게 전체 html에서 titles(제목들), images(포스터 이미지들)를 가져오는 대신
        # 하나의 movie 정보를 감싸고 있는 div 태그를 가져온 다음
        # 그 안에 있는 포스터 이미지, 영화 제목, 평점 등을 가져오면
        # for문을 한번만 돌아도됩니다!

        # 이렇게 css selector를 가지고 받아올 수도 있고
        movies = soup.select('#main > div > div.list.detail > div')
        # 이렇게 속성을 가지고 받아올 수도 있습니다.
        movies = soup.findAll('div', {'itemtype': 'http://schema.org/Movie'})

        # title, image, running_time, score, genre, directors, actors 순으로 넣겠습니다.
        table = []
        for movie in movies:
            row = []

            title = movie.findAll('h4', {'itemprop': 'name'})
            image = movie.findAll('img', {'itemprop': 'image'})
            running_time = movie.findAll('time', {'itemprop': 'duration'})
            score = movie.select('div.rating_txt > div > strong')
            genres = movie.findAll('span', {'itemprop': 'genre'})
            directors = movie.findAll('span', {'itemprop': 'director'})
            actors = movie.findAll('span', {'itemprop': 'actors'})


            # strip()은 앞뒤 공백을 지워줍니다.
            # title가 빈 리스트([])인데, title[0]를 하면 index out of range 에러가 납니다.
            # 에러가 나는 것을 방지해주기 위해서 뒤에 len(title)이 0보다 클때만 title[0]를 하게 하고
            # 아니면 "" 빈 스트링을 row에 append 합니다.
            row.append(title[0].text.strip() if len(title)>0 else "")
            row.append(image[0]['src'].strip() if len(image)>0 else "")
            row.append(running_time[0].text.strip() if len(running_time)>0 else "")
            row.append(score[0].text.strip() if len(score)>0 else "")
            
            # genre, director, actor는 여러명인 경우가 있기 때문에 list로 받아옵니다.
            row.append([genre.text.strip() for genre in genres])
            row.append([director.text.strip() for director in directors])
            row.append([actor.text.strip() for actor in actors])

            # 예상대로라면
            # row <= [u'The Woman in Black 2: Angel of Death (2014)', 'http://ia.media-imdb.com/images/M/MV5BMTgxMjUyNTAxNF5BMl5BanBnXkFtZTgwNTk4MDUyMzE@._V1_UY209_CR0,0,140,209_AL_.jpg', u'98 min', u'42', [u'Drama', u'Horror', u'Thriller'], [u'Tom Harper'], [u'Helen McCrory', u'Jeremy Irvine', u'Phoebe Fox', u'Leanne Best']]
            # print row
    
            table.append(row)

        return table

jan_2015 = movie_crawler('http://www.imdb.com/movies-coming-soon/2015-01')
# print jan_2015[0]

jan_2015
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# [['The Woman in Black 2: Angel of Death (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTgxMjUyNTAxNF5BMl5BanBnXkFtZTgwNTk4MDUyMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '98 min',
#   '42',
#   ['Drama', 'Horror', 'Thriller'],
#   ['Tom Harper'],
#   ['Helen McCrory', 'Jeremy Irvine', 'Phoebe Fox', 'Leanne Best']],
#  ['A Most Violent Year (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE4OTY4ODg3Ml5BMl5BanBnXkFtZTgwMTI1MTg1MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '125 min',
#   '79',
#   ['Action', 'Crime', 'Drama', 'Thriller'],
#   ['J.C. Chandor'],
#   ['Oscar Isaac', 'Jessica Chastain', 'David Oyelowo', 'Alessandro Nivola']],
#  ['Leviafan (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAwMTY3MTU0Ml5BMl5BanBnXkFtZTgwNzE0ODAwMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '140 min',
#   '92',
#   ['Drama'],
#   ['Andrey Zvyagintsev'],
#   ['Aleksey Serebryakov',
#    'Elena Lyadova',
#    'Roman Madyanov',
#    'Vladimir Vdovichenkov']],
#  ['[REC] 4: Apocalipsis (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BOTU3OTU2ODc5MF5BMl5BanBnXkFtZTgwNjY3MDY2MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '53',
#   ['Horror'],
#   ['Jaume Balagueró'],
#   ['Manuela Velasco', 'Paco Manzanedo', 'Héctor Colomé', 'Ismael Fritschi']],
#  ['The Search for General Tso (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BODc5MzA4OTUxOF5BMl5BanBnXkFtZTgwNDA4ODI2MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '71 min',
#   '72',
#   ['Documentary', 'Comedy', 'History', 'Mystery'],
#   ['Ian Cheney'],
#   ['Ian Cheney']],
#  ['Taken 3 (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNjM5MDU3NTY0M15BMl5BanBnXkFtZTgwOTk2ODU2MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '109 min',
#   '26',
#   ['Action', 'Thriller'],
#   ['Olivier Megaton'],
#   ['Liam Neeson', 'Forest Whitaker', 'Maggie Grace', 'Famke Janssen']],
#  ['Die geliebten Schwestern (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY2MjMxNDQ0MF5BMl5BanBnXkFtZTgwNzg3ODI2MzE@._V1._SY296_CR0,0,200,296_UY209_CR0,0,140,209_AL_.jpg',
#   '138 min',
#   '66',
#   ['Drama', 'History', 'Romance'],
#   ['Dominik Graf'],
#   ['Hannah Herzsprung',
#    'Florian Stetter',
#    'Henriette Confurius',
#    'Claudia Messner']],
#  ['Boven is het stil (2013)',
#   'http://ia.media-imdb.com/images/M/MV5BMTM4MDQ4Mzg4N15BMl5BanBnXkFtZTcwNzE3NTU3OQ@@._V1_UY209_CR3,0,140,209_AL_.jpg',
#   '93 min',
#   '72',
#   ['Drama'],
#   ['Nanouk Leopold'],
#   ['Jeroen Willems', 'Henri Garcin', 'Wim Opbrouck', 'Martijn Lakemeier']],
#  ['Paddington (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAxOTMwOTkwNDZeQTJeQWpwZ15BbWU4MDEyMTI1NjMx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '77',
#   ['Animation', 'Comedy', 'Family', 'Fantasy'],
#   ['Paul King'],
#   ['Hugh Bonneville', 'Sally Hawkins', 'Julie Walters', 'Jim Broadbent']],
#  ['The Wedding Ringer (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTk3MjQyNTUxNl5BMl5BanBnXkFtZTgwNjM3Mjk1MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '35',
#   ['Comedy'],
#   ['Jeremy Garelick'],
#   ['Kevin Hart', 'Josh Gad', 'Kaley Cuoco', 'Affion Crockett']],
#  ['Blackhat (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTg1NDUyMzk5NV5BMl5BanBnXkFtZTgwOTk1NzUxMzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '133 min',
#   '51',
#   ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#   ['Michael Mann'],
#   ['Chris Hemsworth', 'Viola Davis', 'Wei Tang', 'Leehom Wang']],
#  ['Still Alice (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjIzNzAxNjY1Nl5BMl5BanBnXkFtZTgwMDg4ODQxMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '72',
#   ['Drama'],
#   ['Richard Glatzer', 'Wash Westmoreland'],
#   ['Julianne Moore', 'Alec Baldwin', 'Kristen Stewart', 'Kate Bosworth']],
#  ['Spare Parts (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc5NzI4NTIyMF5BMl5BanBnXkFtZTgwMzIzNDMxMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '50',
#   ['Drama'],
#   ['Sean McNamara'],
#   ['George Lopez', 'Jamie Lee Curtis', 'Carlos PenaVega', 'Marisa Tomei']],
#  ['Match (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BOTA5NzAxNzMxNV5BMl5BanBnXkFtZTgwNzY2NDE3MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '62',
#   ['Comedy', 'Drama'],
#   ['Stephen Belber'],
#   ['Patrick Stewart', 'Carla Gugino', 'Matthew Lillard', 'Yanis Macheboeuf']],
#  ['Little Accidents (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTcxMTM0Mjc1NV5BMl5BanBnXkFtZTgwOTUyMzU2MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '105 min',
#   '56',
#   ['Drama'],
#   ['Sara Colangelo'],
#   ['Elizabeth Banks', 'Boyd Holbrook', 'Jacob Lofland', 'Josh Lucas']],
#  ['Son of a Gun (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTg4MjUxODczM15BMl5BanBnXkFtZTgwMDY4MjY0MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '102 min',
#   '48',
#   ['Action', 'Crime', 'Drama', 'Thriller'],
#   ['Julius Avery'],
#   ['Ewan McGregor',
#    'Brenton Thwaites',
#    'Alicia Vikander',
#    'Brendan Kerkvliet']],
#  ['The Boy Next Door (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTgxNTEyMTYzOV5BMl5BanBnXkFtZTgwNzQ4OTg5MjE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '91 min',
#   '30',
#   ['Mystery', 'Thriller'],
#   ['Rob Cohen'],
#   ['Jennifer Lopez', 'Ryan Guzman', 'Kristin Chenoweth', 'John Corbett']],
#  ['Mortdecai (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjM3NDcxOTM5Ml5BMl5BanBnXkFtZTgwNTEwNzE0MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '107 min',
#   '27',
#   ['Action', 'Comedy', 'Mystery', 'Romance'],
#   ['David Koepp'],
#   ['Johnny Depp', 'Gwyneth Paltrow', 'Ewan McGregor', 'Olivia Munn']],
#  ['Black Sea (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMyNzI1ODA3OF5BMl5BanBnXkFtZTgwMTI5OTczMzE@._V1._CR54,54,1274,1940_UX140_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '62',
#   ['Adventure', 'Thriller'],
#   ['Kevin Macdonald'],
#   ['Jude Law', 'Scoot McNairy', 'Ben Mendelsohn', 'David Threlfall']],
#  ['Strange Magic (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA0NjU3MTU5OF5BMl5BanBnXkFtZTgwMTYyMDQ3MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '99 min',
#   '25',
#   ['Animation', 'Family', 'Fantasy', 'Musical'],
#   ['Gary Rydstrom'],
#   ['Evan Rachel Wood', 'Elijah Kelley', 'Kristin Chenoweth', 'Maya Rudolph']],
#  ['Cake (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc4NDYzNTcyM15BMl5BanBnXkFtZTgwNjQ5NzQ0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '102 min',
#   '49',
#   ['Drama'],
#   ['Daniel Barnz'],
#   ['Jennifer Aniston', 'Adriana Barraza', 'Anna Kendrick', 'Sam Worthington']],
#  ['Song One (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjM4NDM5NDI1OV5BMl5BanBnXkFtZTgwMDQ4NjE0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '86 min',
#   '48',
#   ['Drama', 'Music'],
#   ['Kate Barker-Froyland'],
#   ['Anne Hathaway', 'Johnny Flynn', 'Mary Steenburgen', 'Lola Kirke']],
#  ['Mommy (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE3NjMwMjc3N15BMl5BanBnXkFtZTgwNDk4MjA0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '139 min',
#   '74',
#   ['Drama'],
#   ['Xavier Dolan'],
#   ['Anne Dorval',
#    'Antoine-Olivier Pilon',
#    'Suzanne Clément',
#    'Patrick Huard']],
#  ['Red Army (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjIxMDYwMTg3M15BMl5BanBnXkFtZTgwMDQ1NzQ0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '84 min',
#   '83',
#   ['Documentary', 'Biography', 'History', 'Sport'],
#   ['Gabe Polsky'],
#   ['Viacheslav Fetisov', 'Scotty Bowman', 'Mark Deakins', 'Anatoli Karpov']],
#  ['The Duke of Burgundy (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE3MDY2NTQ5Nl5BMl5BanBnXkFtZTgwMDIxMDI5MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '104 min',
#   '87',
#   ['Drama', 'Romance'],
#   ['Peter Strickland'],
#   ['Sidse Babett Knudsen', 'Monica Swinn', "Chiara D'Anna", 'Kata Bartsch']],
#  ['Black or White (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTYyMzE2NTE5MV5BMl5BanBnXkFtZTgwNDI3ODI2MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '121 min',
#   '45',
#   ['Drama'],
#   ['Mike Binder'],
#   ['Kevin Costner', 'Octavia Spencer', 'Gillian Jacobs', 'Anthony Mackie']],
#  ['Project Almanac (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUxMjQ2NjI4OV5BMl5BanBnXkFtZTgwODc2NjUwNDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '106 min',
#   '47',
#   ['Sci-Fi', 'Thriller'],
#   ['Dean Israelite'],
#   ['Amy Landecker', "Sofia Black-D'Elia", 'Virginia Gardner', 'Jonny Weston']],
#  ['The Loft (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAyNTM4ODM5NV5BMl5BanBnXkFtZTgwNTA4NDE3MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '108 min',
#   '24',
#   ['Mystery', 'Romance', 'Thriller'],
#   ['Erik Van Looy'],
#   ['Karl Urban', 'James Marsden', 'Wentworth Miller', 'Eric Stonestreet']],
#  ['Wild Card (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAyNjkyOTgzNF5BMl5BanBnXkFtZTgwMTk0MDc2MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '40',
#   ['Action', 'Crime', 'Drama', 'Thriller'],
#   ['Simon West'],
#   ['Jason Statham',
#    'Michael Angarano',
#    'Dominik García-Lorido',
#    'Milo Ventimiglia']],
#  ['Amira & Sam (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjM5MTE1MDY0Nl5BMl5BanBnXkFtZTgwOTE3NTY4MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '90 min',
#   '58',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Sean Mullin'],
#   ['Martin Starr', 'Dina Shihabi', 'Paul Wesley', 'Laith Nakli']],
#  ['Timbuktu (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMwOTQ0NTUyMF5BMl5BanBnXkFtZTgwNDg3NDUxNDE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '97 min',
#   '92',
#   ['Drama'],
#   ['Abderrahmane Sissako'],
#   ['Ibrahim Ahmed', 'Abel Jafri', 'Toulou Kiki', 'Layla Walet Mohamed']],
#  ['Bande de filles (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA5MDM1ODE5NV5BMl5BanBnXkFtZTgwNjg0MTk5MzE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '113 min',
#   '85',
#   ['Drama'],
#   ['Céline Sciamma'],
#   ['Karidja Touré', 'Assa Sylla', 'Lindsay Karamoh', 'Mariétou Touré']]]

# %%
len(jan_2015)
# Out:
# 32

# %%
# 그러면 이제 2015-01부터 2015-12까지 영화정보를 긁어봅시다.

movie_total = []
for i in range(1, 13):
    url = "http://www.imdb.com/movies-coming-soon/2015-" + str(i).zfill(2)
    print ("crawling 2015 - {0}".format(str(i).zfill(2)))
    movie_total += movie_crawler(url)
# Out:
# crawling 2015 - 01
# C:\Users\hp\Anaconda3\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# crawling 2015 - 02
# crawling 2015 - 03
# crawling 2015 - 04
# crawling 2015 - 05
# crawling 2015 - 06
# crawling 2015 - 07
# crawling 2015 - 08
# crawling 2015 - 09
# crawling 2015 - 10
# crawling 2015 - 11
# crawling 2015 - 12

# %%
movie_total
# Out:
# [['The Woman in Black 2: Angel of Death (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTgxMjUyNTAxNF5BMl5BanBnXkFtZTgwNTk4MDUyMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '98 min',
#   '42',
#   ['Drama', 'Horror', 'Thriller'],
#   ['Tom Harper'],
#   ['Helen McCrory', 'Jeremy Irvine', 'Phoebe Fox', 'Leanne Best']],
#  ['A Most Violent Year (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE4OTY4ODg3Ml5BMl5BanBnXkFtZTgwMTI1MTg1MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '125 min',
#   '79',
#   ['Action', 'Crime', 'Drama', 'Thriller'],
#   ['J.C. Chandor'],
#   ['Oscar Isaac', 'Jessica Chastain', 'David Oyelowo', 'Alessandro Nivola']],
#  ['Leviafan (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAwMTY3MTU0Ml5BMl5BanBnXkFtZTgwNzE0ODAwMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '140 min',
#   '92',
#   ['Drama'],
#   ['Andrey Zvyagintsev'],
#   ['Aleksey Serebryakov',
#    'Elena Lyadova',
#    'Roman Madyanov',
#    'Vladimir Vdovichenkov']],
#  ['[REC] 4: Apocalipsis (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BOTU3OTU2ODc5MF5BMl5BanBnXkFtZTgwNjY3MDY2MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '53',
#   ['Horror'],
#   ['Jaume Balagueró'],
#   ['Manuela Velasco', 'Paco Manzanedo', 'Héctor Colomé', 'Ismael Fritschi']],
#  ['The Search for General Tso (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BODc5MzA4OTUxOF5BMl5BanBnXkFtZTgwNDA4ODI2MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '71 min',
#   '72',
#   ['Documentary', 'Comedy', 'History', 'Mystery'],
#   ['Ian Cheney'],
#   ['Ian Cheney']],
#  ['Taken 3 (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNjM5MDU3NTY0M15BMl5BanBnXkFtZTgwOTk2ODU2MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '109 min',
#   '26',
#   ['Action', 'Thriller'],
#   ['Olivier Megaton'],
#   ['Liam Neeson', 'Forest Whitaker', 'Maggie Grace', 'Famke Janssen']],
#  ['Die geliebten Schwestern (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY2MjMxNDQ0MF5BMl5BanBnXkFtZTgwNzg3ODI2MzE@._V1._SY296_CR0,0,200,296_UY209_CR0,0,140,209_AL_.jpg',
#   '138 min',
#   '66',
#   ['Drama', 'History', 'Romance'],
#   ['Dominik Graf'],
#   ['Hannah Herzsprung',
#    'Florian Stetter',
#    'Henriette Confurius',
#    'Claudia Messner']],
#  ['Boven is het stil (2013)',
#   'http://ia.media-imdb.com/images/M/MV5BMTM4MDQ4Mzg4N15BMl5BanBnXkFtZTcwNzE3NTU3OQ@@._V1_UY209_CR3,0,140,209_AL_.jpg',
#   '93 min',
#   '72',
#   ['Drama'],
#   ['Nanouk Leopold'],
#   ['Jeroen Willems', 'Henri Garcin', 'Wim Opbrouck', 'Martijn Lakemeier']],
#  ['Paddington (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAxOTMwOTkwNDZeQTJeQWpwZ15BbWU4MDEyMTI1NjMx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '77',
#   ['Animation', 'Comedy', 'Family', 'Fantasy'],
#   ['Paul King'],
#   ['Hugh Bonneville', 'Sally Hawkins', 'Julie Walters', 'Jim Broadbent']],
#  ['The Wedding Ringer (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTk3MjQyNTUxNl5BMl5BanBnXkFtZTgwNjM3Mjk1MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '35',
#   ['Comedy'],
#   ['Jeremy Garelick'],
#   ['Kevin Hart', 'Josh Gad', 'Kaley Cuoco', 'Affion Crockett']],
#  ['Blackhat (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTg1NDUyMzk5NV5BMl5BanBnXkFtZTgwOTk1NzUxMzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '133 min',
#   '51',
#   ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#   ['Michael Mann'],
#   ['Chris Hemsworth', 'Viola Davis', 'Wei Tang', 'Leehom Wang']],
#  ['Still Alice (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjIzNzAxNjY1Nl5BMl5BanBnXkFtZTgwMDg4ODQxMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '72',
#   ['Drama'],
#   ['Richard Glatzer', 'Wash Westmoreland'],
#   ['Julianne Moore', 'Alec Baldwin', 'Kristen Stewart', 'Kate Bosworth']],
#  ['Spare Parts (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc5NzI4NTIyMF5BMl5BanBnXkFtZTgwMzIzNDMxMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '50',
#   ['Drama'],
#   ['Sean McNamara'],
#   ['George Lopez', 'Jamie Lee Curtis', 'Carlos PenaVega', 'Marisa Tomei']],
#  ['Match (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BOTA5NzAxNzMxNV5BMl5BanBnXkFtZTgwNzY2NDE3MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '62',
#   ['Comedy', 'Drama'],
#   ['Stephen Belber'],
#   ['Patrick Stewart', 'Carla Gugino', 'Matthew Lillard', 'Yanis Macheboeuf']],
#  ['Little Accidents (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTcxMTM0Mjc1NV5BMl5BanBnXkFtZTgwOTUyMzU2MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '105 min',
#   '56',
#   ['Drama'],
#   ['Sara Colangelo'],
#   ['Elizabeth Banks', 'Boyd Holbrook', 'Jacob Lofland', 'Josh Lucas']],
#  ['Son of a Gun (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTg4MjUxODczM15BMl5BanBnXkFtZTgwMDY4MjY0MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '102 min',
#   '48',
#   ['Action', 'Crime', 'Drama', 'Thriller'],
#   ['Julius Avery'],
#   ['Ewan McGregor',
#    'Brenton Thwaites',
#    'Alicia Vikander',
#    'Brendan Kerkvliet']],
#  ['The Boy Next Door (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTgxNTEyMTYzOV5BMl5BanBnXkFtZTgwNzQ4OTg5MjE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '91 min',
#   '30',
#   ['Mystery', 'Thriller'],
#   ['Rob Cohen'],
#   ['Jennifer Lopez', 'Ryan Guzman', 'Kristin Chenoweth', 'John Corbett']],
#  ['Mortdecai (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjM3NDcxOTM5Ml5BMl5BanBnXkFtZTgwNTEwNzE0MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '107 min',
#   '27',
#   ['Action', 'Comedy', 'Mystery', 'Romance'],
#   ['David Koepp'],
#   ['Johnny Depp', 'Gwyneth Paltrow', 'Ewan McGregor', 'Olivia Munn']],
#  ['Black Sea (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMyNzI1ODA3OF5BMl5BanBnXkFtZTgwMTI5OTczMzE@._V1._CR54,54,1274,1940_UX140_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '62',
#   ['Adventure', 'Thriller'],
#   ['Kevin Macdonald'],
#   ['Jude Law', 'Scoot McNairy', 'Ben Mendelsohn', 'David Threlfall']],
#  ['Strange Magic (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA0NjU3MTU5OF5BMl5BanBnXkFtZTgwMTYyMDQ3MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '99 min',
#   '25',
#   ['Animation', 'Family', 'Fantasy', 'Musical'],
#   ['Gary Rydstrom'],
#   ['Evan Rachel Wood', 'Elijah Kelley', 'Kristin Chenoweth', 'Maya Rudolph']],
#  ['Cake (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc4NDYzNTcyM15BMl5BanBnXkFtZTgwNjQ5NzQ0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '102 min',
#   '49',
#   ['Drama'],
#   ['Daniel Barnz'],
#   ['Jennifer Aniston', 'Adriana Barraza', 'Anna Kendrick', 'Sam Worthington']],
#  ['Song One (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjM4NDM5NDI1OV5BMl5BanBnXkFtZTgwMDQ4NjE0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '86 min',
#   '48',
#   ['Drama', 'Music'],
#   ['Kate Barker-Froyland'],
#   ['Anne Hathaway', 'Johnny Flynn', 'Mary Steenburgen', 'Lola Kirke']],
#  ['Mommy (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE3NjMwMjc3N15BMl5BanBnXkFtZTgwNDk4MjA0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '139 min',
#   '74',
#   ['Drama'],
#   ['Xavier Dolan'],
#   ['Anne Dorval',
#    'Antoine-Olivier Pilon',
#    'Suzanne Clément',
#    'Patrick Huard']],
#  ['Red Army (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjIxMDYwMTg3M15BMl5BanBnXkFtZTgwMDQ1NzQ0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '84 min',
#   '83',
#   ['Documentary', 'Biography', 'History', 'Sport'],
#   ['Gabe Polsky'],
#   ['Viacheslav Fetisov', 'Scotty Bowman', 'Mark Deakins', 'Anatoli Karpov']],
#  ['The Duke of Burgundy (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE3MDY2NTQ5Nl5BMl5BanBnXkFtZTgwMDIxMDI5MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '104 min',
#   '87',
#   ['Drama', 'Romance'],
#   ['Peter Strickland'],
#   ['Sidse Babett Knudsen', 'Monica Swinn', "Chiara D'Anna", 'Kata Bartsch']],
#  ['Black or White (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTYyMzE2NTE5MV5BMl5BanBnXkFtZTgwNDI3ODI2MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '121 min',
#   '45',
#   ['Drama'],
#   ['Mike Binder'],
#   ['Kevin Costner', 'Octavia Spencer', 'Gillian Jacobs', 'Anthony Mackie']],
#  ['Project Almanac (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUxMjQ2NjI4OV5BMl5BanBnXkFtZTgwODc2NjUwNDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '106 min',
#   '47',
#   ['Sci-Fi', 'Thriller'],
#   ['Dean Israelite'],
#   ['Amy Landecker', "Sofia Black-D'Elia", 'Virginia Gardner', 'Jonny Weston']],
#  ['The Loft (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAyNTM4ODM5NV5BMl5BanBnXkFtZTgwNTA4NDE3MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '108 min',
#   '24',
#   ['Mystery', 'Romance', 'Thriller'],
#   ['Erik Van Looy'],
#   ['Karl Urban', 'James Marsden', 'Wentworth Miller', 'Eric Stonestreet']],
#  ['Wild Card (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAyNjkyOTgzNF5BMl5BanBnXkFtZTgwMTk0MDc2MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '40',
#   ['Action', 'Crime', 'Drama', 'Thriller'],
#   ['Simon West'],
#   ['Jason Statham',
#    'Michael Angarano',
#    'Dominik García-Lorido',
#    'Milo Ventimiglia']],
#  ['Amira & Sam (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjM5MTE1MDY0Nl5BMl5BanBnXkFtZTgwOTE3NTY4MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '90 min',
#   '58',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Sean Mullin'],
#   ['Martin Starr', 'Dina Shihabi', 'Paul Wesley', 'Laith Nakli']],
#  ['Timbuktu (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMwOTQ0NTUyMF5BMl5BanBnXkFtZTgwNDg3NDUxNDE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '97 min',
#   '92',
#   ['Drama'],
#   ['Abderrahmane Sissako'],
#   ['Ibrahim Ahmed', 'Abel Jafri', 'Toulou Kiki', 'Layla Walet Mohamed']],
#  ['Bande de filles (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA5MDM1ODE5NV5BMl5BanBnXkFtZTgwNjg0MTk5MzE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '113 min',
#   '85',
#   ['Drama'],
#   ['Céline Sciamma'],
#   ['Karidja Touré', 'Assa Sylla', 'Lindsay Karamoh', 'Mariétou Touré']],
#  ['Jupiter Ascending (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQyNzk2MjA2NF5BMl5BanBnXkFtZTgwMjEwNzk3MjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '127 min',
#   '40',
#   ['Action', 'Adventure', 'Sci-Fi'],
#   ['Lana Wachowski', 'Lilly Wachowski'],
#   ['Channing Tatum', 'Mila Kunis', 'Eddie Redmayne', 'Sean Bean']],
#  ['Seventh Son (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAxNTg2MDkyN15BMl5BanBnXkFtZTgwNzA3NzY1MjE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '102 min',
#   '30',
#   ['Action', 'Adventure', 'Fantasy'],
#   ['Sergei Bodrov'],
#   ['Ben Barnes', 'Julianne Moore', 'Jeff Bridges', 'Alicia Vikander']],
#  ['The SpongeBob Movie: Sponge Out of Water (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjYyNDczNTE0MF5BMl5BanBnXkFtZTgwNjkzNDYxMzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '62',
#   ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#   ['Paul Tibbitt', 'Mike Mitchell'],
#   ['Tom Kenny', 'Antonio Banderas', 'Bill Fagerbakke', 'Clancy Brown']],
#  ['Ballet 422 (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUxMjk2MDM2NF5BMl5BanBnXkFtZTgwOTMzOTUzMzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '75 min',
#   '74',
#   ['Documentary', 'Music', 'Sport'],
#   ['Jody Lee Lipes'],
#   ['Justin Peck', 'Tiler Peck', 'Sterling Hyltin', 'Amar Ramasar']],
#  ['Fifty Shades of Grey (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE1MTM4NDAzOF5BMl5BanBnXkFtZTgwNTMwNjI0MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '125 min',
#   '46',
#   ['Drama', 'Romance'],
#   ['Sam Taylor-Johnson'],
#   ['Dakota Johnson', 'Jamie Dornan', 'Jennifer Ehle', 'Eloise Mumford']],
#  ['Kingsman: The Secret Service (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTkxMjgwMDM4Ml5BMl5BanBnXkFtZTgwMTk3NTIwNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '129 min',
#   '58',
#   ['Action', 'Adventure', 'Comedy', 'Crime', 'Thriller'],
#   ['Matthew Vaughn'],
#   ['Colin Firth', 'Taron Egerton', 'Samuel L. Jackson', 'Michael Caine']],
#  ['The Last Five Years (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTA2MTMwMjIxMTdeQTJeQWpwZ15BbWU4MDAwMTYxNzMx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '94 min',
#   '60',
#   ['Comedy', 'Drama', 'Musical', 'Romance'],
#   ['Richard LaGravenese'],
#   ['Anna Kendrick', 'Jeremy Jordan', 'Tamara Mintz', 'Cassandra Inman']],
#  ['What We Do in the Shadows (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAwNDA5NzEwM15BMl5BanBnXkFtZTgwMTA1MDUyNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '86 min',
#   '76',
#   ['Comedy', 'Fantasy', 'Horror'],
#   ['Jemaine Clement', 'Taika Waititi'],
#   ['Jemaine Clement', 'Taika Waititi', 'Cori Gonzalez-Macuer', 'Jonny Brugh']],
#  ['Old Fashioned (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjcxNzk4ODM3Nl5BMl5BanBnXkFtZTgwODA4OTI5MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '115 min',
#   '29',
#   ['Drama', 'Romance'],
#   ['Rik Swartzwelder'],
#   ['Elizabeth Roberts', 'Rik Swartzwelder', 'LeJon Woods', 'Tyler Hollinger']],
#  ['Hot Tub Time Machine 2 (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU3NzQzMzE0NV5BMl5BanBnXkFtZTgwMDM4MTI0NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '93 min',
#   '29',
#   ['Comedy', 'Sci-Fi'],
#   ['Steve Pink'],
#   ['Rob Corddry', 'Craig Robinson', 'Clark Duke', 'Adam Scott']],
#  ['The DUFF (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc3OTg3MDUwN15BMl5BanBnXkFtZTgwMTAwMTkxNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '56',
#   ['Comedy'],
#   ['Ari Sandel'],
#   ['Mae Whitman', 'Bella Thorne', 'Robbie Amell', 'Allison Janney']],
#  ['McFarland, USA (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMwNjY2Mjk5OV5BMl5BanBnXkFtZTgwODM2NTA0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '129 min',
#   '60',
#   ['Biography', 'Drama', 'Sport'],
#   ['Niki Caro'],
#   ['Kevin Costner', 'Maria Bello', 'Ramiro Rodriguez', 'Carlos Pratts']],
#  ['Relatos salvajes (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNzAzMjA1ODAxOV5BMl5BanBnXkFtZTgwODg4NTQzNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '122 min',
#   '77',
#   ['Comedy', 'Drama', 'Thriller'],
#   ['Damián Szifrón'],
#   ['Darío Grandinetti', 'María Marull', 'Mónica Villa', 'Rita Cortese']],
#  ['Gloria (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNzE0NDAyNzk5NF5BMl5BanBnXkFtZTgwMzA3OTcyNjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '126 min',
#   '',
#   ['Biography', 'Drama', 'Music'],
#   ['Christian Keller'],
#   ['Sofía Espinosa', 'Marco Pérez', 'Tatiana del Real', 'Karla Rodriguez']],
#  ['Focus (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUwODg2OTA4OF5BMl5BanBnXkFtZTgwOTE5MTE4MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '105 min',
#   '56',
#   ['Comedy', 'Crime', 'Drama', 'Romance'],
#   ['Glenn Ficarra', 'John Requa'],
#   ['Will Smith', 'Margot Robbie', 'Rodrigo Santoro', 'Adrian Martinez']],
#  ['The Lazarus Effect (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjM2ODM1OTA0M15BMl5BanBnXkFtZTgwMDMxMDI5MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '83 min',
#   '31',
#   ['Horror', 'Sci-Fi', 'Thriller'],
#   ['David Gelb'],
#   ['Olivia Wilde', 'Mark Duplass', 'Evan Peters', 'Sarah Bolger']],
#  ['Maps to the Stars (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY3MjQwNzYyNV5BMl5BanBnXkFtZTgwNTY3NDQ5MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '111 min',
#   '67',
#   ['Comedy', 'Drama'],
#   ['David Cronenberg'],
#   ['Julianne Moore', 'Mia Wasikowska', 'Robert Pattinson', 'John Cusack']],
#  ["'71 (2014)",
#   'http://ia.media-imdb.com/images/M/MV5BMTg1NjE5Njg4M15BMl5BanBnXkFtZTgwMzEyODAzNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '99 min',
#   '83',
#   ['Action', 'Drama', 'Thriller', 'War'],
#   ['Yann Demange'],
#   ["Jack O'Connell", 'Sam Reid', 'Sean Harris', 'Paul Popplewell']],
#  ['The Hunting Ground (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNjc4Mjk3ODgxMl5BMl5BanBnXkFtZTgwMjc3OTQ1NDE@._V1_UY209_CR3,0,140,209_AL_.jpg',
#   '103 min',
#   '77',
#   ['Documentary'],
#   ['Kirby Dick'],
#   ['Andrea Pino', 'Annie Clark', 'Claire Potter', 'Melinda Manning']],
#  ['A la mala (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNjEzODA5OTU3Nl5BMl5BanBnXkFtZTgwMzcyODAxNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '99 min',
#   '',
#   ['Comedy'],
#   ['Pedro Pablo Ibarra'],
#   ['Aislinn Derbez', 'Mauricio Ochmann', 'Aurora Papile', 'Luis Arrieta']],
#  ['Everly (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjEyNTU4NTE5NV5BMl5BanBnXkFtZTgwNzY4NzIxNDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '35',
#   ['Action', 'Thriller'],
#   ['Joe Lynch'],
#   ['Salma Hayek', 'Hiroyuki Watanabe', 'Laura Cepeda', 'Togo Igawa']],
#  ['The Salvation (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTA5MTU2NjIxOTNeQTJeQWpwZ15BbWU4MDA5Njc0MDIx._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '92 min',
#   '64',
#   ['Drama', 'Western'],
#   ['Kristian Levring'],
#   ['Mads Mikkelsen', 'Eva Green', 'Eric Cantona', 'Mikael Persbrandt']],
#  ['My Life Directed by Nicolas Winding Refn (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjEwNDg1ODQ2Nl5BMl5BanBnXkFtZTgwOTU1NzM3MjE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '58 min',
#   '50',
#   ['Documentary'],
#   ['Liv Corfixen'],
#   ['Liv Corfixen',
#    'Nicolas Winding Refn',
#    'Ryan Gosling',
#    'Alejandro Jodorowsky']],
#  ['Chappie (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUyNTI4NTIwNl5BMl5BanBnXkFtZTgwMjQ4MTI0NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '120 min',
#   '41',
#   ['Action', 'Crime', 'Drama', 'Sci-Fi', 'Thriller'],
#   ['Neill Blomkamp'],
#   ['Sharlto Copley', 'Dev Patel', 'Hugh Jackman', 'Sigourney Weaver']],
#  ['The Second Best Exotic Marigold Hotel (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU3MjkxNjc0OV5BMl5BanBnXkFtZTgwMjc0NDg0NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '122 min',
#   '51',
#   ['Comedy', 'Drama'],
#   ['John Madden'],
#   ['Judi Dench', 'Maggie Smith', 'Bill Nighy', 'Dev Patel']],
#  ['Unfinished Business (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNjg5NzU5ODE5OV5BMl5BanBnXkFtZTgwMjM1MjE2NDE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '91 min',
#   '32',
#   ['Comedy'],
#   ['Ken Scott'],
#   ['Vince Vaughn', 'Dave Franco', 'Tom Wilkinson', 'James Marsden']],
#  ['Merchants of Doubt (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTA0MDMzMzU2ODJeQTJeQWpwZ15BbWU4MDQxMTE4NTQx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '96 min',
#   '70',
#   ['Documentary'],
#   ['Robert Kenner'],
#   ['Frederick Singer', 'Naomi Oreskes', 'Jamy Ian Swiss', 'Sam Roe']],
#  ['Compared to What: The Improbable Journey of Barney Frank (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BOTk2OTE4NzQ3NF5BMl5BanBnXkFtZTgwNTcxODQwNDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '87 min',
#   '',
#   ['Documentary', 'Biography', 'Drama'],
#   ['Sheila Canavan', 'Michael Chandler'],
#   ['Barney Frank', 'Spencer Bachus', 'Mike Barnicle', 'Neil Barofsky']],
#  ['Cinderella (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMxODYyODEzN15BMl5BanBnXkFtZTgwMDk4OTU0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '105 min',
#   '67',
#   ['Drama', 'Family', 'Fantasy', 'Romance'],
#   ['Kenneth Branagh'],
#   ['Lily James', 'Cate Blanchett', 'Richard Madden', 'Helena Bonham Carter']],
#  ['Run All Night (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU2ODI3ODEyOV5BMl5BanBnXkFtZTgwMTM3NTQzNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '59',
#   ['Action', 'Crime', 'Drama', 'Thriller'],
#   ['Jaume Collet-Serra'],
#   ['Liam Neeson', 'Ed Harris', 'Joel Kinnaman', "Vincent D'Onofrio"]],
#  ['It Follows (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUwMDEzNDI1MF5BMl5BanBnXkFtZTgwNzAyODU5MzE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '100 min',
#   '83',
#   ['Horror', 'Mystery'],
#   ['David Robert Mitchell'],
#   ['Maika Monroe', 'Keir Gilchrist', 'Olivia Luccardi', 'Lili Sepe']],
#  ['Seymour: An Introduction (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BODg4MDA4MjA5N15BMl5BanBnXkFtZTgwMzI0MTU1NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '84 min',
#   '83',
#   ['Documentary', 'Biography', 'Music'],
#   ['Ethan Hawke'],
#   ['Seymour Bernstein', 'Jiyang Chen', 'Ethan Hawke', 'Junko Ichikawa']],
#  ['The Wrecking Crew! (2008)',
#   'http://ia.media-imdb.com/images/M/MV5BMjI4NTkzNjk2Ml5BMl5BanBnXkFtZTgwNjgwNDM3NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '67',
#   ['Documentary', 'Music'],
#   ['Denny Tedesco'],
#   ['Denny Tedesco', 'Brian Wilson', 'Dick Clark', 'Cher']],
#  ['Insurgent (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTgxOTYxMTg3OF5BMl5BanBnXkFtZTgwMDgyMzA2NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '119 min',
#   '42',
#   ['Adventure', 'Sci-Fi', 'Thriller'],
#   ['Robert Schwentke'],
#   ['Shailene Woodley', 'Ansel Elgort', 'Theo James', 'Kate Winslet']],
#  ['The Gunman (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE2MzE5ODY5MF5BMl5BanBnXkFtZTgwNTI0NjM1NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '115 min',
#   '39',
#   ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#   ['Pierre Morel'],
#   ['Sean Penn', 'Idris Elba', 'Jasmine Trinca', 'Javier Bardem']],
#  ['Do You Believe? (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE5MzAxMjUyMl5BMl5BanBnXkFtZTgwNDk1OTMwNDE@._V1_UY209_CR11,0,140,209_AL_.jpg',
#   '120 min',
#   '22',
#   ['Drama'],
#   ['Jon Gunn'],
#   ['Mira Sorvino', 'Sean Astin', 'Alexa PenaVega', 'Ted McGinley']],
#  ['Kumiko, the Treasure Hunter (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAzNzI1MTkyNzBeQTJeQWpwZ15BbWU4MDQ0NDU0MzQx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '105 min',
#   '68',
#   ['Drama'],
#   ['David Zellner'],
#   ['Rinko Kikuchi', 'Nobuyuki Katsube', 'Kanako Higashi', 'Ichi Kyokaku']],
#  ['Danny Collins (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNDk5NTYxOTk2MV5BMl5BanBnXkFtZTgwMzIxMjE0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '106 min',
#   '58',
#   ['Comedy', 'Drama', 'Music'],
#   ['Dan Fogelman'],
#   ['Al Pacino', 'Annette Bening', 'Jennifer Garner', 'Bobby Cannavale']],
#  ['Spring (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMwNzM2OTk3OF5BMl5BanBnXkFtZTgwNjExOTU0NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '109 min',
#   '69',
#   ['Horror', 'Romance', 'Sci-Fi'],
#   ['Justin Benson', 'Aaron Moorhead'],
#   ['Lou Taylor Pucci', 'Nadia Hilker', 'Francesco Carnelutti', 'Nick Nevern']],
#  ["Can't Stand Losing You (2012)",
#   'http://ia.media-imdb.com/images/M/MV5BMTQyNTU1MzkzMV5BMl5BanBnXkFtZTgwMTE4MzE2NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '79 min',
#   '33',
#   ['Documentary', 'Biography', 'History', 'Music'],
#   ['Andy Grieve', 'Lauren Lazin'],
#   ['Sting', 'Andy Summers', 'Stewart Copeland']],
#  ['Get Hard (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc3OTc1NjM0M15BMl5BanBnXkFtZTgwNjAyMzE1MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '100 min',
#   '34',
#   ['Comedy', 'Crime'],
#   ['Etan Cohen'],
#   ['Will Ferrell', 'Kevin Hart', 'Alison Brie', 'T.I.']],
#  ['Home (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU0MzU4ODI3Ml5BMl5BanBnXkFtZTgwMzQzODk5NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '94 min',
#   '55',
#   ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Sci-Fi'],
#   ['Tim Johnson'],
#   ['Jim Parsons', 'Rihanna', 'Steve Martin', 'Jennifer Lopez']],
#  ["While We're Young (2014)",
#   'http://ia.media-imdb.com/images/M/MV5BMTc4MDEzMTA5MF5BMl5BanBnXkFtZTgwODA5MTM0NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '97 min',
#   '77',
#   ['Comedy', 'Drama'],
#   ['Noah Baumbach'],
#   ['Ben Stiller', 'Naomi Watts', 'Adam Driver', 'Amanda Seyfried']],
#  ['Serena (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTExMDY2OTYxMTNeQTJeQWpwZ15BbWU4MDc2NDE5MTQx._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '109 min',
#   '36',
#   ['Drama', 'Romance'],
#   ['Susanne Bier'],
#   ['Bradley Cooper', 'Jennifer Lawrence', 'Toby Jones', 'Rhys Ifans']],
#  ['The Salt of the Earth (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNjkyNjI3ODc0Ml5BMl5BanBnXkFtZTgwMTU0MjM2NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '110 min',
#   '83',
#   ['Documentary', 'Biography', 'History'],
#   ['Juliano Ribeiro Salgado', 'Wim Wenders'],
#   ['Sebastião Salgado',
#    'Wim Wenders',
#    'Lélia Wanick Salgado',
#    'Juliano Ribeiro Salgado']],
#  ['The Riot Club (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAxNTA3NjI0NF5BMl5BanBnXkFtZTgwODcyMjQ3MjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '107 min',
#   '54',
#   ['Drama', 'Thriller'],
#   ['Lone Scherfig'],
#   ['Sam Claflin', 'Max Irons', 'Douglas Booth', 'Jessica Brown Findlay']],
#  ['Fehér isten (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNjk4MzkyOTQwNF5BMl5BanBnXkFtZTgwODE5MTk1MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '121 min',
#   '80',
#   ['Drama', 'Thriller'],
#   ['Kornél Mundruczó'],
#   ['Zsófia Psotta', 'Sándor Zsótér', 'Lili Horváth', 'Szabolcs Thuróczy']],
#  ['Man from Reno (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE5NDA2NDg1N15BMl5BanBnXkFtZTgwNjM1NDQ1MzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '111 min',
#   '69',
#   ['Crime', 'Drama', 'Mystery', 'Thriller'],
#   ['Dave Boyle'],
#   ['Ayako Fujitani', 'Pepe Serna', 'Kazuki Kitamura', 'Yasuyo Shiba']],
#  ['Cupcakes (2013)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA2MzU2MTQzMF5BMl5BanBnXkFtZTgwMDEwMzk1NDE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '92 min',
#   '64',
#   ['Comedy', 'Music'],
#   ['Eytan Fox'],
#   ['Dana Ivgy', 'Keren Berger', 'Yael Bar-Zohar', 'Efrat Dor']],
#  ['A Girl Like Her (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ5NTE4MDAzMF5BMl5BanBnXkFtZTgwNDc4NjIyNDE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '91 min',
#   '54',
#   ['Drama'],
#   ['Amy S. Weber'],
#   ['Lexi Ainsworth', 'Hunter King', 'Jimmy Bennett', 'Amy S. Weber']],
#  ['Furious Seven (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQxOTA2NDUzOV5BMl5BanBnXkFtZTgwNzY2MTMxMzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '137 min',
#   '67',
#   ['Action', 'Crime', 'Thriller'],
#   ['James Wan'],
#   ['Vin Diesel', 'Paul Walker', 'Dwayne Johnson', 'Jason Statham']],
#  ['Woman in Gold (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTExMTUxNDQ5MjdeQTJeQWpwZ15BbWU4MDk4NTgxMzQx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '109 min',
#   '51',
#   ['Biography', 'Drama', 'History'],
#   ['Simon Curtis'],
#   ['Helen Mirren', 'Ryan Reynolds', 'Daniel Brühl', 'Katie Holmes']],
#  ['5 to 7 (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ4Mzg3ODQ4M15BMl5BanBnXkFtZTgwMjA3NjE1NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '52',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Victor Levin'],
#   ['Anton Yelchin', 'Bérénice Marlohe', 'Olivia Thirlby', 'Lambert Wilson']],
#  ['Lambert & Stamp (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNzM2OTEyNTUwOF5BMl5BanBnXkFtZTgwMDU5Nzk4NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '117 min',
#   '75',
#   ['Documentary', 'Biography', 'History', 'Music'],
#   ['James D. Cooper'],
#   ['Kit Lambert', 'Roger Daltrey', 'Pete Townshend', 'Richard Barnes']],
#  ['Effie Gray (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAyNjQ1NDc3Nl5BMl5BanBnXkFtZTgwNjY5MTE0NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '104 min',
#   '54',
#   ['Drama'],
#   ['Richard Laxton'],
#   ['Dakota Fanning', 'Greg Wise', 'Tom Sturridge', 'Emma Thompson']],
#  ['The Longest Ride (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMzIzMjg0NjQwNF5BMl5BanBnXkFtZTgwODAwOTE4MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '128 min',
#   '33',
#   ['Drama', 'Romance'],
#   ['George Tillman Jr.'],
#   ['Scott Eastwood', 'Britt Robertson', 'Alan Alda', 'Jack Huston']],
#  ['Ex Machina (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUxNzc0OTIxMV5BMl5BanBnXkFtZTgwNDI3NzU2NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '108 min',
#   '78',
#   ['Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#   ['Alex Garland'],
#   ['Alicia Vikander', 'Domhnall Gleeson', 'Oscar Isaac', 'Sonoya Mizuno']],
#  ['Desert Dancer (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjI5NzA2NjQ2MV5BMl5BanBnXkFtZTgwNzgzNTEyNDE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '104 min',
#   '49',
#   ['Biography', 'Drama'],
#   ['Richard Raymond'],
#   ['Nazanin Boniadi', 'Freida Pinto', 'Tom Cullen', 'Reece Ritchie']],
#  ['Clouds of Sils Maria (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAwMTg3MDE0NF5BMl5BanBnXkFtZTgwNjQ1ODQyNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '124 min',
#   '78',
#   ['Drama'],
#   ['Olivier Assayas'],
#   ['Juliette Binoche',
#    'Kristen Stewart',
#    'Chloë Grace Moretz',
#    'Lars Eidinger']],
#  ['Kill Me Three Times (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ0ODcxMjc1Ml5BMl5BanBnXkFtZTgwNDI4OTg1NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '90 min',
#   '30',
#   ['Action', 'Comedy', 'Thriller'],
#   ['Kriv Stenders'],
#   ['Simon Pegg', 'Teresa Palmer', 'Alice Braga', 'Luke Hemsworth']],
#  ['Lost River (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc4MzU4NDA2M15BMl5BanBnXkFtZTgwNTM3MDMzNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '42',
#   ['Drama', 'Fantasy', 'Mystery', 'Thriller'],
#   ['Ryan Gosling'],
#   ['Christina Hendricks',
#    'Iain De Caestecker',
#    'Matt Smith',
#    'Saoirse Ronan']],
#  ["While We're Young (2014)",
#   'http://ia.media-imdb.com/images/M/MV5BMTc4MDEzMTA5MF5BMl5BanBnXkFtZTgwODA5MTM0NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '97 min',
#   '77',
#   ['Comedy', 'Drama'],
#   ['Noah Baumbach'],
#   ['Ben Stiller', 'Naomi Watts', 'Adam Driver', 'Amanda Seyfried']],
#  ['Danny Collins (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNDk5NTYxOTk2MV5BMl5BanBnXkFtZTgwMzIxMjE0MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '106 min',
#   '58',
#   ['Comedy', 'Drama', 'Music'],
#   ['Dan Fogelman'],
#   ['Al Pacino', 'Annette Bening', 'Jennifer Garner', 'Bobby Cannavale']],
#  ['Paul Blart: Mall Cop 2 (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTkwMjkxNDQ1MV5BMl5BanBnXkFtZTgwNDQwODIxNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '94 min',
#   '13',
#   ['Action', 'Comedy', 'Crime'],
#   ['Andy Fickman'],
#   ['Kevin James', 'Raini Rodriguez', 'Eduardo Verástegui', 'Daniella Alonso']],
#  ['Cybernatural (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMzdlNWI2MjYtMWY3ZC00N2EzLWIzNTgtZDY2NGI4OTY3Yzc5XkEyXkFqcGdeQXVyMjQwMjk0NjI@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '83 min',
#   '59',
#   ['Horror', 'Mystery', 'Thriller'],
#   ['Levan Gabriadze'],
#   ['Heather Sossaman',
#    'Matthew Bohrer',
#    'Courtney Halverson',
#    'Shelley Hennig']],
#  ['Child 44 (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTk1NTkxOTc5Nl5BMl5BanBnXkFtZTgwODI0NTg0NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '137 min',
#   '41',
#   ['Crime', 'Drama', 'Thriller'],
#   ['Daniel Espinosa'],
#   ['Tom Hardy', 'Gary Oldman', 'Noomi Rapace', 'Joel Kinnaman']],
#  ['Monkey Kingdom (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMzIxNDc1MDg0MF5BMl5BanBnXkFtZTgwNTI3ODE4MzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '81 min',
#   '72',
#   ['Documentary'],
#   ['Mark Linfield', 'Alastair Fothergill'],
#   ['Tina Fey']],
#  ['True Story (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAzNTc5MTA0NzleQTJeQWpwZ15BbWU4MDU1MDM2NzMx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '99 min',
#   '50',
#   ['Crime', 'Drama', 'Mystery', 'Thriller'],
#   ['Rupert Goold'],
#   ['James Franco', 'Jonah Hill', 'Felicity Jones', 'Maria Dizzia']],
#  ['Alex of Venice (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUxMTUxMDcxNl5BMl5BanBnXkFtZTgwODc0Mjk1NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '86 min',
#   '56',
#   ['Drama'],
#   ['Chris Messina'],
#   ['Mary Elizabeth Winstead', 'Chris Messina', 'Don Johnson', 'Derek Luke']],
#  ['Beyond the Reach (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE5MTYyOTM4MV5BMl5BanBnXkFtZTgwNzI5MTk1NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '91 min',
#   '34',
#   ['Thriller'],
#   ['Jean-Baptiste Léonetti'],
#   ['Michael Douglas',
#    'Jeremy Irvine',
#    'Martin Palmer',
#    'Hanna Mangan Lawrence']],
#  ['Félix et Meira (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTkzNjY3Mjk3OV5BMl5BanBnXkFtZTgwODYzODE1NDE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '105 min',
#   '66',
#   ['Drama', 'Romance'],
#   ['Maxime Giroux'],
#   ['Martin Dubreuil', 'Hadas Yaron', 'Luzer Twersky', 'Melissa Weisz']],
#  ['Monsters: Dark Continent (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMzA5ODI3OTQ3NV5BMl5BanBnXkFtZTgwODI4NzMwNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '119 min',
#   '42',
#   ['Drama', 'Sci-Fi', 'Thriller'],
#   ['Tom Green'],
#   ['Johnny Harris', 'Sam Keeley', 'Joe Dempsie', 'Sofia Boutella']],
#  ['The Dead Lands (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjg5MTM0MjU0NF5BMl5BanBnXkFtZTgwMDI1MDU2MjE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '107 min',
#   '59',
#   ['Action'],
#   ['Toa Fraser'],
#   ['James Rolleston', 'Lawrence Makoare', 'Te Kohe Tuhaka', 'Xavier Horan']],
#  ['The Age of Adaline (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAzMTQzMTA2MjheQTJeQWpwZ15BbWU4MDk2MTg2MzUx._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '112 min',
#   '51',
#   ['Drama', 'Fantasy', 'Romance'],
#   ['Lee Toland Krieger'],
#   ['Blake Lively', 'Michiel Huisman', 'Harrison Ford', 'Kathy Baker']],
#  ['Little Boy (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU5MjMyODcxMF5BMl5BanBnXkFtZTgwMzIwMDM2NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '106 min',
#   '30',
#   ['Drama', 'War'],
#   ['Alejandro Monteverde'],
#   ['Jakob Salvati', 'Emily Watson', 'David Henrie', 'Michael Rapaport']],
#  ['Ex Machina (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUxNzc0OTIxMV5BMl5BanBnXkFtZTgwNDI3NzU2NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '108 min',
#   '78',
#   ['Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#   ['Alex Garland'],
#   ['Alicia Vikander', 'Domhnall Gleeson', 'Oscar Isaac', 'Sonoya Mizuno']],
#  ['The Water Diviner (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMzODA4NDYzM15BMl5BanBnXkFtZTgwMTc0Mzc0NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '111 min',
#   '50',
#   ['Drama', 'War'],
#   ['Russell Crowe'],
#   ['Russell Crowe', 'Olga Kurylenko', 'Jai Courtney', 'Isabel Lucas']],
#  ['Adult Beginners (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY1NTI4NDU5Ml5BMl5BanBnXkFtZTgwOTYwMDcyNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '57',
#   ['Comedy', 'Drama'],
#   ['Ross Katz'],
#   ['Nick Kroll', 'Rose Byrne', 'Bobby Cannavale', 'Joel McHale']],
#  ['Misery Loves Comedy (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BODM0MjExMzkxNl5BMl5BanBnXkFtZTgwNzM1Mzc3NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '94 min',
#   '51',
#   ['Documentary', 'Comedy'],
#   ['Kevin Pollak'],
#   ['Amy Schumer', 'James L. Brooks', 'Judd Apatow', 'Whoopi Goldberg']],
#  ['Avengers: Age of Ultron (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTM4OGJmNWMtOTM4Ni00NTE3LTg3MDItZmQxYjc4N2JhNmUxXkEyXkFqcGdeQXVyNTgzMDMzMTg@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '141 min',
#   '66',
#   ['Action', 'Adventure', 'Sci-Fi'],
#   ['Joss Whedon'],
#   ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo', 'Chris Hemsworth']],
#  ['Far from the Madding Crowd (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNzI4NzUwNDgwN15BMl5BanBnXkFtZTgwNTI3MjMwNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '119 min',
#   '71',
#   ['Drama', 'Romance'],
#   ['Thomas Vinterberg'],
#   ['Carey Mulligan',
#    'Matthias Schoenaerts',
#    'Michael Sheen',
#    'Tom Sturridge']],
#  ['Welcome to Me (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTA0NTAyNTYwNDheQTJeQWpwZ15BbWU4MDY2ODcyNTQx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '87 min',
#   '69',
#   ['Comedy', 'Drama'],
#   ['Shira Piven'],
#   ['Kristen Wiig', 'James Marsden', 'Linda Cardellini', 'Wes Bentley']],
#  ['Mandariinid (2013)',
#   'http://ia.media-imdb.com/images/M/MV5BMTgwNzA3MDQzOV5BMl5BanBnXkFtZTgwNTE5MDE5NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '87 min',
#   '73',
#   ['Drama', 'War'],
#   ['Zaza Urushadze'],
#   ['Lembit Ulfsak', 'Elmo Nüganen', 'Giorgi Nakashidze', 'Misha Meskhi']],
#  ['Iris (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNDMzMDY1NTE4MV5BMl5BanBnXkFtZTgwODc4NjY3NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '79 min',
#   '80',
#   ['Documentary', 'Biography', 'History'],
#   ['Albert Maysles'],
#   ['Carl Apfel', 'Harold Koda', 'Dries Van Noten', 'Inez Bailey']],
#  ['Hundraåringen som klev ut genom fönstret och försvann (2013)',
#   'http://ia.media-imdb.com/images/M/MV5BNDUyMzU5MTk5MF5BMl5BanBnXkFtZTgwNjcxNDQxNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '58',
#   ['Adventure', 'Comedy'],
#   ['Felix Herngren'],
#   ['Robert Gustafsson', 'Iwar Wiklander', 'David Wiberg', 'Mia Skäringer']],
#  ['Ride (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU1Njc1Mzk4NF5BMl5BanBnXkFtZTgwMTU2MzQ3NDE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '93 min',
#   '48',
#   ['Comedy'],
#   ['Helen Hunt'],
#   ['Helen Hunt', 'Brenton Thwaites', 'Luke Wilson', 'Robert Knepper']],
#  ['Loin des hommes (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTA1MTgxOTkwMzdeQTJeQWpwZ15BbWU4MDIzODk1NDUx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '74',
#   ['Drama', 'War', 'Western'],
#   ['David Oelhoffen'],
#   ['Viggo Mortensen', 'Reda Kateb', 'Djemel Barek', 'Vincent Martin']],
#  ['Hyena (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTk1ODk1Njg3MV5BMl5BanBnXkFtZTgwMjA5MjQxNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '112 min',
#   '56',
#   ['Crime', 'Drama'],
#   ['Gerard Johnson'],
#   ['Peter Ferdinando', 'Stephen Graham', 'Neil Maskell', 'Elisa Lasowski']],
#  ['Días de gracia (2011)',
#   'http://ia.media-imdb.com/images/M/MV5BNDM3OTU0NjIzMV5BMl5BanBnXkFtZTgwMjE0ODA1NTE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '133 min',
#   '58',
#   ['Crime', 'Thriller'],
#   ['Everardo Gout'],
#   ['Carlos Bardem',
#    'Kristyan Ferrer',
#    'Tenoch Huerta',
#    'José Alberto Solorzano']],
#  ['Hot Pursuit (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNzc0MDk0NDMwM15BMl5BanBnXkFtZTgwNTIzMjE1NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '87 min',
#   '31',
#   ['Action', 'Comedy', 'Crime'],
#   ['Anne Fletcher'],
#   ['Reese Witherspoon',
#    'Sofía Vergara',
#    'Matthew Del Negro',
#    'Michael Mosley']],
#  ['The D Train (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ3ODQzNDE2Ml5BMl5BanBnXkFtZTgwOTM1NzQwNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '55',
#   ['Comedy', 'Drama'],
#   ['Andrew Mogel', 'Jarrad Paul'],
#   ['Jack Black', 'James Marsden', 'Kathryn Hahn', 'Jeffrey Tambor']],
#  ['5 Flights Up (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ5MzU3MzgwN15BMl5BanBnXkFtZTgwNjM2NDQ3NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '55',
#   ['Drama'],
#   ['Richard Loncraine'],
#   ['Diane Keaton', 'Morgan Freeman', 'Cynthia Nixon', 'Alysia Reiner']],
#  ['Maggie (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTkyNzk0MTU2Ml5BMl5BanBnXkFtZTgwNDExNzMyNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '52',
#   ['Drama', 'Horror'],
#   ['Henry Hobson'],
#   ['Arnold Schwarzenegger',
#    'Abigail Breslin',
#    'Joely Richardson',
#    'Laura Cayouette']],
#  ['Saint Laurent (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ4NjMzMDk2NV5BMl5BanBnXkFtZTgwMDAxODMyNTE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '150 min',
#   '52',
#   ['Biography', 'Drama', 'Romance'],
#   ['Bertrand Bonello'],
#   ['Gaspard Ulliel', 'Jérémie Renier', 'Louis Garrel', 'Léa Seydoux']],
#  ['I Am Big Bird: The Caroll Spinney Story (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTkyMDEyMjYxMF5BMl5BanBnXkFtZTgwODE2Mzc3NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '90 min',
#   '71',
#   ['Documentary', 'Biography', 'Drama'],
#   ['Dave LaMattina', 'Chad N. Walker'],
#   ['Caroll Spinney', 'Jim Henson', 'Frank Oz', 'Debra Spinney']],
#  ['Noble (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU1NDY2NDE2M15BMl5BanBnXkFtZTgwMzc1NzUwNDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '100 min',
#   '63',
#   ['Biography', 'Drama'],
#   ['Stephen Bradley'],
#   ["Deirdre O'Kane", 'Sarah Greene', 'Gloria Cramer Curtis', 'Brendan Coyle']],
#  ['The Seven Five (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjEwMzA0NTM4Nl5BMl5BanBnXkFtZTgwMzMxMzI2NTE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '104 min',
#   '69',
#   ['Documentary'],
#   ['Tiller Russell'],
#   ['Michael Dowd', 'Ken Eurell', 'Walter Yurkiw', 'Chickie']],
#  ['Skin Trade (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAxMTY5NTgxMDVeQTJeQWpwZ15BbWU4MDAyODEwMTUx._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '96 min',
#   '39',
#   ['Action', 'Crime', 'Thriller'],
#   ['Ekachai Uekrongtham'],
#   ['Dolph Lundgren', 'Tony Jaa', 'Ron Perlman', 'Michael Jai White']],
#  ['Mad Max: Fury Road (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUyMTE0ODcxNF5BMl5BanBnXkFtZTgwODE4NDQzNTE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '120 min',
#   '90',
#   ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   ['George Miller'],
#   ['Tom Hardy', 'Charlize Theron', 'Nicholas Hoult', 'Zoë Kravitz']],
#  ['Pitch Perfect 2 (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTk0Mzg4NDYyOF5BMl5BanBnXkFtZTgwOTM2ODg2NTE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '115 min',
#   '63',
#   ['Comedy', 'Music'],
#   ['Elizabeth Banks'],
#   ['Anna Kendrick', 'Rebel Wilson', 'Hailee Steinfeld', 'Brittany Snow']],
#  ["I'll See You in My Dreams (2015)",
#   'http://ia.media-imdb.com/images/M/MV5BMTYzMzc5OTkyOV5BMl5BanBnXkFtZTgwNzc3OTMyNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '75',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Brett Haley'],
#   ['Blythe Danner', 'Martin Starr', 'Sam Elliott', 'Malin Akerman']],
#  ['Good Kill (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTkzNDIxNzE5OF5BMl5BanBnXkFtZTgwODMxMTExNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '102 min',
#   '63',
#   ['Drama', 'Thriller'],
#   ['Andrew Niccol'],
#   ['Ethan Hawke', 'January Jones', 'Zoë Kravitz', 'Fatima El Bahraquy']],
#  ['La French (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNzY2MjcxOTA4Nl5BMl5BanBnXkFtZTgwNjAwOTYwNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '135 min',
#   '67',
#   ['Action', 'Crime', 'Thriller'],
#   ['Cédric Jimenez'],
#   ['Jean Dujardin', 'Gilles Lellouche', 'Céline Sallette', 'Mélanie Doutey']],
#  ['Set Fire to the Stars (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ0MDcxOTU4NF5BMl5BanBnXkFtZTgwOTYxMDQ2NTE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '97 min',
#   '49',
#   ['Biography', 'Drama'],
#   ['Andy Goddard'],
#   ['Elijah Wood', 'Celyn Jones', 'Kelly Reilly', 'Steven Mackintosh']],
#  ['Where Hope Grows (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY1MjUxOTU0OF5BMl5BanBnXkFtZTgwMDYxNTQ0NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '41',
#   ['Drama'],
#   ['Chris Dowling'],
#   ['Kristoffer Polaha', 'David DeSanctis', 'McKaley Miller', 'Michael Grant']],
#  ['El Crítico (2013)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ5NzY2Nzg4OF5BMl5BanBnXkFtZTgwMDEwMzI0NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '98 min',
#   '40',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Hernán Guerschuny'],
#   ['Rafael Spregelburd', 'Dolores Fonzi', 'Blanca Lewin', 'Ignacio Rogers']],
#  ['Tomorrowland (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ0MDc5MjAyNF5BMl5BanBnXkFtZTgwMzU5Mzk1NjE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '130 min',
#   '60',
#   ['Action', 'Adventure', 'Family', 'Mystery', 'Sci-Fi'],
#   ['Brad Bird'],
#   ['George Clooney', 'Britt Robertson', 'Hugh Laurie', 'Raffey Cassidy']],
#  ['Poltergeist (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjIzNTI1ODgwM15BMl5BanBnXkFtZTgwMDYwODA1NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '93 min',
#   '47',
#   ['Horror', 'Thriller'],
#   ['Gil Kenan'],
#   ['Sam Rockwell', 'Rosemarie DeWitt', 'Kennedi Clements', 'Saxon Sharbino']],
#  ['Omoide no Mânî (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ1ODY3MTc5MF5BMl5BanBnXkFtZTgwOTUyNDI2NTE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '103 min',
#   '72',
#   ['Animation', 'Drama', 'Family', 'Mystery'],
#   ['Hiromasa Yonebayashi'],
#   ['Sara Takatsuki',
#    'Kasumi Arimura',
#    'Nanako Matsushima',
#    'Susumu Terajima']],
#  ['Aloft (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMjAyMzY2MTAxOF5BMl5BanBnXkFtZTgwOTQwOTEzNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '112 min',
#   '34',
#   ['Drama'],
#   ['Claudia Llosa'],
#   ['Jennifer Connelly', 'Cillian Murphy', 'Mélanie Laurent', 'Oona Chaplin']],
#  ['Chocolate City (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY3Mzg2OTk2Nl5BMl5BanBnXkFtZTgwNDU0MDE1NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '91 min',
#   '',
#   ['Drama'],
#   ['Jean-Claude La Marre'],
#   ["Robert Ri'chard", 'Tyson Beckford', 'DeRay Davis', 'Vivica A. Fox']],
#  ['Mita Tova (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ4OTY3NzAyM15BMl5BanBnXkFtZTgwOTM3Mzk0NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '71',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Tal Granit', 'Sharon Maymon'],
#   ["Ze'ev Revach", 'Levana Finkelstein', 'Aliza Rosen', 'Ilan Dar']],
#  ['Sunshine Superman (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTEwNDQyODk1OTReQTJeQWpwZ15BbWU4MDQwNzIzOTQx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '100 min',
#   '70',
#   ['Documentary', 'Biography', 'Sport'],
#   ['Marah Strauch'],
#   ['John Long', 'Marah Strauch', 'Cecilie Bull', 'Allison McCulloch']],
#  ['San Andreas (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNjI4MTgyOTAxOV5BMl5BanBnXkFtZTgwMjQwOTA4NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '43',
#   ['Action', 'Adventure', 'Drama', 'Thriller'],
#   ['Brad Peyton'],
#   ['Dwayne Johnson', 'Carla Gugino', 'Alexandra Daddario', 'Colton Haynes']],
#  ['Aloha (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTg4Mjc0NTE1NV5BMl5BanBnXkFtZTgwNzcwNTQ3NTE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '105 min',
#   '40',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Cameron Crowe'],
#   ['Bradley Cooper', 'Rachel McAdams', 'Emma Stone', 'Alec Baldwin']],
#  ['Results (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ4MjEzMzQ1Ml5BMl5BanBnXkFtZTgwODUyNTQzNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '105 min',
#   '73',
#   ['Comedy', 'Romance'],
#   ['Andrew Bujalski'],
#   ['Guy Pearce', 'Cobie Smulders', 'Kevin Corrigan', 'Giovanni Ribisi']],
#  ['Gemma Bovery (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BNTE5NTI4MjM5Ml5BMl5BanBnXkFtZTgwNDkzMjY0NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '99 min',
#   '58',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Anne Fontaine'],
#   ['Fabrice Luchini',
#    'Gemma Arterton',
#    'Jason Flemyng',
#    'Isabelle Candelier']],
#  ['Heaven Knows What (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTg2ODQzNzgzN15BMl5BanBnXkFtZTgwMzkxOTY2NTE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '97 min',
#   '75',
#   ['Drama'],
#   ['Ben Safdie', 'Joshua Safdie'],
#   ['Arielle Holmes', 'Caleb Landry Jones', 'Buddy Duress', 'Ron Braunstein']],
#  ['Entourage (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BZTBiZGNkNzktNTYzNC00MjE4LTk1NTYtYTM3NTQ4NmEzNWYwXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '104 min',
#   '38',
#   ['Comedy'],
#   ['Doug Ellin'],
#   ['Adrian Grenier', 'Kevin Connolly', 'Jerry Ferrara', 'Kevin Dillon']],
#  ['Spy (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNjI5OTQ0MDQxM15BMl5BanBnXkFtZTgwMzcwNjMyNTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '119 min',
#   '75',
#   ['Action', 'Comedy', 'Crime'],
#   ['Paul Feig'],
#   ['Melissa McCarthy', 'Rose Byrne', 'Jude Law', 'Jason Statham']],
#  ['Insidious: Chapter 3 (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUwNDU4NjE1N15BMl5BanBnXkFtZTgwOTc0MzA5NDE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '97 min',
#   '52',
#   ['Fantasy', 'Horror', 'Thriller'],
#   ['Leigh Whannell'],
#   ['Dermot Mulroney', 'Stefanie Scott', 'Angus Sampson', 'Leigh Whannell']],
#  ['Love & Mercy (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTk1MTkwMzU4Nl5BMl5BanBnXkFtZTgwNjY0MDE1NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '121 min',
#   '80',
#   ['Biography', 'Drama', 'Music'],
#   ['Bill Pohlad'],
#   ['John Cusack', 'Paul Dano', 'Elizabeth Banks', 'Paul Giamatti']],
#  ['Testament of Youth (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAyOTI3OTgwMTdeQTJeQWpwZ15BbWU4MDAwNzM2NDUx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '129 min',
#   '76',
#   ['Biography', 'Drama', 'History', 'War'],
#   ['James Kent'],
#   ['Alicia Vikander', 'Kit Harington', 'Taron Egerton', 'Dominic West']],
#  ['En duva satt på en gren och funderade på tillvaron (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY0MzQ5MTQzMl5BMl5BanBnXkFtZTgwMTUzNTA4NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '81',
#   ['Comedy', 'Drama'],
#   ['Roy Andersson'],
#   ['Holger Andersson', 'Nils Westblom', 'Viktor Gyllenberg', 'Lotti Törnros']],
#  ['Hungry Hearts (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTkxMTg5Mzg2MF5BMl5BanBnXkFtZTgwNjMzNTA4NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '109 min',
#   '48',
#   ['Drama', 'Thriller'],
#   ['Saverio Costanzo'],
#   ['Adam Driver', 'Alba Rohrwacher', 'Roberta Maxwell', 'Al Roffe']],
#  ['Ging Chat Goo Si (2013)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUwODUyNDM3NV5BMl5BanBnXkFtZTgwNzk0MzA2NTE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '110 min',
#   '44',
#   ['Action', 'Crime', 'Drama', 'Thriller'],
#   ['Ding Sheng'],
#   ['Jackie Chan', 'Ye Liu', 'Tian Jing', 'Tao Yin']],
#  ['Jurassic World (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ5MTE0MTk3Nl5BMl5BanBnXkFtZTgwMjczMzk2NTE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '124 min',
#   '59',
#   ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   ['Colin Trevorrow'],
#   ['Chris Pratt', 'Bryce Dallas Howard', 'Ty Simpkins', 'Judy Greer']],
#  ['Me and Earl and the Dying Girl (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNTA1NzUzNjY4MV5BMl5BanBnXkFtZTgwNDU0MDI0NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '105 min',
#   '74',
#   ['Comedy', 'Drama'],
#   ['Alfonso Gomez-Rejon'],
#   ['Thomas Mann', 'RJ Cyler', 'Olivia Cooke', 'Nick Offerman']],
#  ['The Wolfpack (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMzg2NjE5OTQwNl5BMl5BanBnXkFtZTgwNjYwNDk2NTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '90 min',
#   '75',
#   ['Documentary', 'Biography'],
#   ['Crystal Moselle'],
#   ['Bhagavan Angulo', 'Govinda Angulo', 'Jagadisa Angulo', 'Krsna Angulo']],
#  ['Set Fire to the Stars (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ0MDcxOTU4NF5BMl5BanBnXkFtZTgwOTYxMDQ2NTE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '97 min',
#   '49',
#   ['Biography', 'Drama'],
#   ['Andy Goddard'],
# ...
#   ['Comedy'],
#   ['Jessie Nelson'],
#   ['Steve Martin', 'Diane Keaton', 'John Goodman', 'Ed Helms']],
#  ['My All-American (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU3ODA0MjI0Ml5BMl5BanBnXkFtZTgwNTUwNDQxNjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '118 min',
#   '34',
#   ['Biography', 'Drama', 'Sport'],
#   ['Angelo Pizzo'],
#   ['Aaron Eckhart', 'Finn Wittrock', 'Robin Tunney', 'Sarah Bolger']],
#  ['By the Sea (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUyNDU2MDMxM15BMl5BanBnXkFtZTgwMzAzMTk1NjE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '122 min',
#   '44',
#   ['Drama', 'Romance'],
#   ['Angelina Jolie'],
#   ['Brad Pitt', 'Angelina Jolie', 'Mélanie Laurent', 'Melvil Poupaud']],
#  ['Prem Ratan Dhan Payo (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjUzMjE1MzIxOF5BMl5BanBnXkFtZTgwMjgyMzc5NjE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '164 min',
#   '',
#   ['Action', 'Drama', 'Family', 'Musical', 'Romance'],
#   ['Sooraj R. Barjatya'],
#   ['Salman Khan', 'Sonam Kapoor', 'Neil Nitin Mukesh', 'Deepak Dobriyal']],
#  ['James White (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE4MzU2NjEwN15BMl5BanBnXkFtZTgwNDQyMDE3NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '85 min',
#   '83',
#   ['Drama'],
#   ['Josh Mond'],
#   ['Christopher Abbott', 'Cynthia Nixon', 'Scott Mescudi', 'Ron Livingston']],
#  ['Entertainment (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTA5OTEyMTQwODFeQTJeQWpwZ15BbWU4MDA0MzMyNDYx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '103 min',
#   '65',
#   ['Drama'],
#   ['Rick Alverson'],
#   ['Gregg Turkington', 'John C. Reilly', 'Tye Sheridan', 'Amy Seimetz']],
#  ['Jag är Ingrid (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMzOTEyNjM3NF5BMl5BanBnXkFtZTgwNTY4MDk5NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '75',
#   ['Documentary', 'Biography'],
#   ['Stig Björkman'],
#   ['Ingrid Bergman',
#    'Roberto Rossellini',
#    'Pia Lindström',
#    'Isotta Rossellini']],
#  ['Kajaki (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ5MjQ2MjU5NV5BMl5BanBnXkFtZTgwMzI2Mzg5NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '108 min',
#   '',
#   ['Adventure', 'Drama', 'Thriller', 'War'],
#   ['Paul Katis'],
#   ['David Elliot', 'Mark Stanley', 'Scott Kyle', "Benjamin O'Mahony"]],
#  ['The Hunger Games: Mockingjay - Part 2 (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNjQzNDI2NTU1Ml5BMl5BanBnXkFtZTgwNTAyMDQ5NjE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '137 min',
#   '65',
#   ['Adventure', 'Sci-Fi'],
#   ['Francis Lawrence'],
#   ['Jennifer Lawrence',
#    'Josh Hutcherson',
#    'Liam Hemsworth',
#    'Woody Harrelson']],
#  ['The Night Before (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTkyNDY1ODQwNV5BMl5BanBnXkFtZTgwNzA2MjUwNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '101 min',
#   '58',
#   ['Comedy'],
#   ['Jonathan Levine'],
#   ['Joseph Gordon-Levitt', 'Seth Rogen', 'Jillian Bell', 'Lizzy Caplan']],
#  ['Secret in Their Eyes (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE0ODU1NDE0Ml5BMl5BanBnXkFtZTgwNzc4Njc3NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '111 min',
#   '45',
#   ['Crime', 'Drama', 'Mystery', 'Thriller'],
#   ['Billy Ray'],
#   ['Chiwetel Ejiofor', 'Nicole Kidman', 'Julia Roberts', 'Dean Norris']],
#  ['Legend (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMDQ4MGY0NWUtY2MxOC00YzI5LTg0OTEtZjNmY2Q2ZmM0MTA1XkEyXkFqcGdeQXVyNTQzOTc3MTI@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '132 min',
#   '55',
#   ['Biography', 'Crime', 'Drama', 'History', 'Thriller'],
#   ['Brian Helgeland'],
#   ['Tom Hardy', 'Emily Browning', 'Taron Egerton', 'Paul Anderson']],
#  ['Carol (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjE3Nzk2NTMxMl5BMl5BanBnXkFtZTgwOTk5ODcyODE@._V1_UY209_CR4,0,140,209_AL_.jpg',
#   '118 min',
#   '95',
#   ['Drama', 'Romance'],
#   ['Todd Haynes'],
#   ['Cate Blanchett', 'Rooney Mara', 'Sarah Paulson', 'Kyle Chandler']],
#  ['#Horror (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjMyNTQwNzc4OF5BMl5BanBnXkFtZTgwOTQzMTgyNzE@._V1_UY209_CR4,0,140,209_AL_.jpg',
#   '101 min',
#   '42',
#   ['Drama', 'Horror', 'Mystery', 'Thriller'],
#   ['Tara Subkoff'],
#   ['Sadie Seelert', 'Haley Murphy', 'Bridget McGarry', 'Blue Lindeberg']],
#  ['Mediterranea (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNzE5MTk2NzM1Ml5BMl5BanBnXkFtZTgwODYzMTgyNzE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '107 min',
#   '77',
#   ['Drama'],
#   ['Jonas Carpignano'],
#   ['Alassane Sy', 'Koudous Seihon', 'Paolo Sciarretta', 'Aisha']],
#  ['The Good Dinosaur (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc5MTg2NjQ4MV5BMl5BanBnXkFtZTgwNzcxOTY5NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '93 min',
#   '66',
#   ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#   ['Peter Sohn'],
#   ['Jeffrey Wright',
#    'Frances McDormand',
#    'Maleah Nipay-Padilla',
#    'Ryan Teeple']],
#  ['Creed (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BODg5NDM1MDI4NF5BMl5BanBnXkFtZTgwMzg0MzQxNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '133 min',
#   '82',
#   ['Drama', 'Sport'],
#   ['Ryan Coogler'],
#   ['Michael B. Jordan',
#    'Sylvester Stallone',
#    'Tessa Thompson',
#    'Phylicia Rashad']],
#  ['Victor Frankenstein (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc2Mjk0MTM0NF5BMl5BanBnXkFtZTgwNjgyOTg1NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '110 min',
#   '36',
#   ['Drama', 'Horror', 'Sci-Fi', 'Thriller'],
#   ['Paul McGuigan'],
#   ['Daniel Radcliffe',
#    'James McAvoy',
#    'Jessica Brown Findlay',
#    'Andrew Scott']],
#  ['The Danish Girl (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA0NjA4NjE2Nl5BMl5BanBnXkFtZTgwNzIxNTY2NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '119 min',
#   '66',
#   ['Biography', 'Drama', 'Romance'],
#   ['Tom Hooper'],
#   ['Eddie Redmayne', 'Alicia Vikander', 'Amber Heard', 'Ben Whishaw']],
#  ['Janis: Little Girl Blue (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BODg1OTc5ODM5N15BMl5BanBnXkFtZTgwMTk0OTg4NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '103 min',
#   '74',
#   ['Documentary', 'Biography', 'Music'],
#   ['Amy Berg'],
#   ['Cat Power', 'Janis Joplin', 'Karleen Bennett', 'Laura Joplin']],
#  ['Tom Swift and His Electric Rifle (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTc5NzQ2NTIxMF5BMl5BanBnXkFtZTgwMjU4NjExNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '100 min',
#   '70',
#   ['Documentary', 'Drama'],
#   ['Nick Berardini'],
#   ['Rick Smith', 'Tom Smith']],
#  ['Krampus (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjk0MjMzMTI3NV5BMl5BanBnXkFtZTgwODEyODkxNzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '98 min',
#   '49',
#   ['Comedy', 'Fantasy', 'Horror'],
#   ['Michael Dougherty'],
#   ['Adam Scott', 'Toni Collette', 'David Koechner', 'Allison Tolman']],
#  ['Chi-Raq (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNTMwNzkxMDUxN15BMl5BanBnXkFtZTgwOTM5NjQzNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '127 min',
#   '77',
#   ['Comedy', 'Crime', 'Drama', 'Musical'],
#   ['Spike Lee'],
#   ['Nick Cannon', 'Teyonah Parris', 'Wesley Snipes', 'Angela Bassett']],
#  ['The Letters (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTYyMzg0Njg5MV5BMl5BanBnXkFtZTgwOTQ3MTkwNjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '25',
#   ['Drama'],
#   ['William Riead'],
#   ['Juliet Stevenson', 'Rutger Hauer', 'Max von Sydow', 'Priya Darshini']],
#  ['Macbeth (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA5NjgyMzY1NV5BMl5BanBnXkFtZTgwOTk3NTY2NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '113 min',
#   '71',
#   ['Drama', 'War'],
#   ['Justin Kurzel'],
#   ['Michael Fassbender', 'Marion Cotillard', 'Jack Madigan', 'Frank Madigan']],
#  ['Youth (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjI2OTk5MzYyMl5BMl5BanBnXkFtZTgwMzY1MjE3NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '124 min',
#   '64',
#   ['Comedy', 'Drama', 'Music'],
#   ['Paolo Sorrentino'],
#   ['Michael Caine', 'Harvey Keitel', 'Rachel Weisz', 'Jane Fonda']],
#  ['A Royal Night Out (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNDg4MjE5OTUyM15BMl5BanBnXkFtZTgwMjM4NzkyNzE@._V1._CR28,31,698,1031_UY209_CR0,0,140,209_AL_.jpg',
#   '97 min',
#   '58',
#   ['Comedy', 'Drama', 'Romance'],
#   ['Julian Jarrold'],
#   ['Sarah Gadon', 'Bel Powley', 'Emily Watson', 'Rupert Everett']],
#  ['Kawaki (2014)',
#   'http://ia.media-imdb.com/images/M/MV5BMTgxMDQ5ODQ2OV5BMl5BanBnXkFtZTgwMDYxOTQxNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '118 min',
#   '55',
#   ['Crime', 'Drama', 'Horror', 'Mystery'],
#   ['Tetsuya Nakashima'],
#   ['Kôji Yakusho', 'Nana Komatsu', 'Satoshi Tsumabuki', 'Hiroya Shimizu']],
#  ['Life (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTA3Mzc5Nzk0ODReQTJeQWpwZ15BbWU4MDA2ODQxMTcx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '111 min',
#   '59',
#   ['Biography', 'Drama'],
#   ['Anton Corbijn'],
#   ['Robert Pattinson', 'Dane DeHaan', 'Peter Lucas', 'Lauren Gallagher']],
#  ['Hitchcock/Truffaut (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTU1MDcxODk2OV5BMl5BanBnXkFtZTgwNzA5Nzc2NTE@._V1_UY209_CR2,0,140,209_AL_.jpg',
#   '79 min',
#   '79',
#   ['Documentary'],
#   ['Kent Jones'],
#   ['Mathieu Amalric', 'Wes Anderson', 'Peter Bogdanovich', 'David Fincher']],
#  ['Christmas Eve (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY0MjEyMzQ1Nl5BMl5BanBnXkFtZTgwMTEwMjkxNzE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '95 min',
#   '24',
#   ['Comedy'],
#   ['Mitch Davis'],
#   ['Patrick Stewart', 'Jon Heder', 'James Roday', 'Cheryl Hines']],
#  ['Spooks: The Greater Good (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjQyNzAxNjQwN15BMl5BanBnXkFtZTgwMTIyNTMwNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '104 min',
#   '47',
#   ['Action', 'Drama', 'Thriller'],
#   ['Bharat Nalluri'],
#   ['Kit Harington', 'Peter Firth', 'Jennifer Ehle', 'Michael Wildman']],
#  ['In the Heart of the Sea (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA5NzUwODExM15BMl5BanBnXkFtZTgwNjM0MzE4NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '122 min',
#   '47',
#   ['Action', 'Adventure', 'Biography', 'Drama', 'History', 'Thriller'],
#   ['Ron Howard'],
#   ['Chris Hemsworth', 'Cillian Murphy', 'Brendan Gleeson', 'Ben Whishaw']],
#  ['Legend (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMDQ4MGY0NWUtY2MxOC00YzI5LTg0OTEtZjNmY2Q2ZmM0MTA1XkEyXkFqcGdeQXVyNTQzOTc3MTI@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '132 min',
#   '55',
#   ['Biography', 'Crime', 'Drama', 'History', 'Thriller'],
#   ['Brian Helgeland'],
#   ['Tom Hardy', 'Emily Browning', 'Taron Egerton', 'Paul Anderson']],
#  ['The Big Short (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNzlhOTRmZjgtN2YyOS00MjI0LWJiNmMtODQyNTJjNDY1YWU3XkEyXkFqcGdeQXVyMzg2MzE2OTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '130 min',
#   '81',
#   ['Biography', 'Comedy', 'Drama', 'History'],
#   ['Adam McKay'],
#   ['Christian Bale', 'Steve Carell', 'Ryan Gosling', 'Brad Pitt']],
#  ['The Lady in the Van (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BOTY0MjM3NTQyOF5BMl5BanBnXkFtZTgwMzcwNjUxNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '104 min',
#   '70',
#   ['Biography', 'Comedy', 'Drama'],
#   ['Nicholas Hytner'],
#   ['Maggie Smith', 'Alex Jennings', 'Jim Broadbent', 'Clare Hammond']],
#  ['Don Verdean (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAzODQyMjM3NTleQTJeQWpwZ15BbWU4MDc2NDY5MDcx._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '90 min',
#   '39',
#   ['Adventure', 'Comedy', 'Drama'],
#   ['Jared Hess'],
#   ['Sam Rockwell', 'Amy Ryan', 'Jemaine Clement', 'Danny McBride']],
#  ['O Menino e o Mundo (2013)',
#   'http://ia.media-imdb.com/images/M/MV5BMTY4MTAwODg1NF5BMl5BanBnXkFtZTgwMTUyMDQyNzE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '80 min',
#   '80',
#   ['Animation', 'Adventure', 'Family'],
#   ['Alê Abreu'],
#   ['Vinicius Garcia', 'Marco Aurélio Campos', 'Lu Horta', 'Felipe Zilse']],
#  ['Bleeding Heart (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTg2MDY3MTEzOV5BMl5BanBnXkFtZTgwNzQ2ODcwNzE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '80 min',
#   '',
#   ['Drama'],
#   ['Diane Bell'],
#   ['Jessica Biel', 'Zosia Mamet', 'Joe Anderson', 'Edi Gathegi']],
#  ['Star Wars: Episode VII - The Force Awakens (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BOTAzODEzNDAzMl5BMl5BanBnXkFtZTgwMDU1MTgzNzE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '136 min',
#   '81',
#   ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   ['J.J. Abrams'],
#   ['Daisy Ridley', 'John Boyega', 'Oscar Isaac', 'Domhnall Gleeson']],
#  ['Sisters (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjM3MzQ5NDE5MF5BMl5BanBnXkFtZTgwODE5OTQyNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '118 min',
#   '58',
#   ['Comedy'],
#   ['Jason Moore'],
#   ['Amy Poehler', 'Tina Fey', 'Maya Rudolph', 'Ike Barinholtz']],
#  ['Alvin and the Chipmunks: The Road Chip (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTQ1NjQyNTkyOF5BMl5BanBnXkFtZTgwNzA3OTUyNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '92 min',
#   '33',
#   ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Music'],
#   ['Walt Becker'],
#   ['Jason Lee', 'Jesica Ahlberg', 'Josh Green', 'Tony Hale']],
#  ['Saul fia (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUxNjk0NTczMV5BMl5BanBnXkFtZTgwNzIzMTEzNzE@._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '107 min',
#   '89',
#   ['Drama', 'Thriller', 'War'],
#   ['László Nemes'],
#   ['Géza Röhrig', 'Levente Molnár', 'Urs Rechn', 'Todd Charmont']],
#  ["La dame dans l'auto avec des lunettes et un fusil (2015)",
#   'http://ia.media-imdb.com/images/M/MV5BMTY1Njc5NDMyNV5BMl5BanBnXkFtZTgwNzM2ODQ0NzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '93 min',
#   '',
#   ['Thriller'],
#   ['Joann Sfar'],
#   ['Freya Mavor', 'Benjamin Biolay', 'Elio Germano', 'Stacy Martin']],
#  ['Noma My Perfect Storm (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTUzNDYwMzI4MF5BMl5BanBnXkFtZTgwMTA4NTYyNzE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '100 min',
#   '47',
#   ['Documentary'],
#   ['Pierre Deschamps'],
#   ['Rene Redzepi']],
#  ['Extraction (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTAzNjU4MzYwNDdeQTJeQWpwZ15BbWU4MDg3NTEzMjcx._V1_UY209_CR1,0,140,209_AL_.jpg',
#   '83 min',
#   '25',
#   ['Action', 'Thriller'],
#   ['Steven C. Miller'],
#   ['Bruce Willis', 'Kellan Lutz', 'Gina Carano', 'D.B. Sweeney']],
#  ['Joy (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNzRiOWZmMzUtZTJiOC00MjQ1LTkwMjgtNzhlYzBmODAzYTA0XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '124 min',
#   '56',
#   ['Biography', 'Comedy', 'Drama'],
#   ['David O. Russell'],
#   ['Jennifer Lawrence', 'Robert De Niro', 'Bradley Cooper', 'Edgar Ramírez']],
#  ['Point Break (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjIxNDkzOTAyNV5BMl5BanBnXkFtZTgwNjEyOTY3NjE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '114 min',
#   '34',
#   ['Action', 'Crime', 'Sport', 'Thriller'],
#   ['Ericson Core'],
#   ['Edgar Ramírez', 'Luke Bracey', 'Ray Winstone', 'Teresa Palmer']],
#  ["Daddy's Home (2015)",
#   'http://ia.media-imdb.com/images/M/MV5BMTQ0OTE1MTk4N15BMl5BanBnXkFtZTgwMDM5OTk5NjE@._V1_UX140_CR0,0,140,209_AL_.jpg',
#   '96 min',
#   '42',
#   ['Comedy'],
#   ['Sean Anders'],
#   ['Will Ferrell',
#    'Mark Wahlberg',
#    'Linda Cardellini',
#    'Thomas Haden Church']],
#  ['Concussion (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTYwNjgwNDg0NV5BMl5BanBnXkFtZTgwMzY1MjAyNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '123 min',
#   '55',
#   ['Biography', 'Drama', 'Sport'],
#   ['Peter Landesman'],
#   ['Will Smith', 'Alec Baldwin', 'Albert Brooks', 'David Morse']],
#  ['The Big Short (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BNzlhOTRmZjgtN2YyOS00MjI0LWJiNmMtODQyNTJjNDY1YWU3XkEyXkFqcGdeQXVyMzg2MzE2OTE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '130 min',
#   '81',
#   ['Biography', 'Comedy', 'Drama', 'History'],
#   ['Adam McKay'],
#   ['Christian Bale', 'Steve Carell', 'Ryan Gosling', 'Brad Pitt']],
#  ['The Hateful Eight (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjA1MTc1NTg5NV5BMl5BanBnXkFtZTgwOTM2MDEzNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '187 min',
#   '68',
#   ['Crime', 'Drama', 'Mystery', 'Thriller', 'Western'],
#   ['Quentin Tarantino'],
#   ['Samuel L. Jackson',
#    'Kurt Russell',
#    'Jennifer Jason Leigh',
#    'Walton Goggins']],
#  ['The Revenant (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMjU4NDExNDM1NF5BMl5BanBnXkFtZTgwMDIyMTgxNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '156 min',
#   '76',
#   ['Adventure', 'Drama', 'Thriller', 'Western'],
#   ['Alejandro G. Iñárritu'],
#   ['Leonardo DiCaprio', 'Tom Hardy', 'Will Poulter', 'Domhnall Gleeson']],
#  ['45 Years (2015)',
#   'http://ia.media-imdb.com/images/M/MV5BMTgxMTQ4NzMyN15BMl5BanBnXkFtZTgwODA0MTgyNzE@._V1_UY209_CR0,0,140,209_AL_.jpg',
#   '95 min',
#   '94',
#   ['Drama', 'Romance'],
#   ['Andrew Haigh'],
#   ['Charlotte Rampling', 'Tom Courtenay', 'Geraldine James', 'Dolly Wells']]]

# %%
len(movie_total)
# Out:
# 389

# %%
# 그러면 이제 2015-01부터 2015-12까지 영화정보를 긁어봅시다.
target_url = 'http://www.imdb.com/movies-coming-soon/{0}'
movie_total = []
for i in range(1,13):
    # string.zfill(2)을 사용해보세요. zero padding이 생깁니다.
    date = "2015-" + str(i).zfill(2)
    print target_url.format(date) + " crawling.."
    movie_total += movie_crawler(target_url.format(date))

# %%
print "총" + str(len(movie_total)) + "개의 영화 정보를 크롤링했습니다."

# 3개만 출력해봅시다.
for i in range(0,3):
    print "========================================"
    print movie_total[i]

# %%
print('hello %%pythhon')

sfdkjksljflsfjsfd
# Out:
# hello python
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a0a85f86e269> in <module>
#       1 print('hello python')
# ----> 2 sfdkjksljflsfjsfd
#
# NameError: name 'sfdkjksljflsfjsfd' is not defined
